# %% [markdown]
# ### 1.导入

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
from sklearn import preprocessing, metrics
from sklearn.preprocessing import LabelEncoder
import gc
import os
from datetime import datetime,timedelta
from tqdm.notebook import tqdm
from scipy.sparse import csr_matrix
from google.colab import drive
import joblib
from sklearn.model_selection import KFold, GroupKFold, StratifiedKFold
import math
from math import ceil
from datetime import datetime
# drive.mount('/content/drive/')
# os.chdir("drive/My Drive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
CAL_DTYPES={"event_name_1": "category", "event_name_2": "category", "event_type_1": "category",
         "event_type_2": "category", "weekday": "category", 'wm_yr_wk': 'int16', "wday": "int16",
        "month": "int16", "year": "int16", "snap_CA": "float32", 'snap_TX': 'float32', 'snap_WI': 'float32' }
PRICE_DTYPES = {"item_id": "category", "store_id": "category", "wm_yr_wk": "int16", "sell_price": "float32" }

# %%
h = 28
tr_last = 1941
def create_dt(nrows = None, first_day = 1200):
    prices = pd.read_csv("./sell_prices.csv", dtype = PRICE_DTYPES)
    for col, col_dtype in PRICE_DTYPES.items():
        if col_dtype == "category":
            prices[col] = prices[col].cat.codes.astype("int16")
            prices[col] -= prices[col].min()
    cal = pd.read_csv("./calendar.csv", dtype = CAL_DTYPES)
    cal["date"] = pd.to_datetime(cal["date"])
    for col, col_dtype in CAL_DTYPES.items():
        if col_dtype == "category":
            cal[col] = cal[col].cat.codes.astype("int16")
            cal[col] -= cal[col].min()
    start_day = max(1, first_day)
    numcols = [f"d_{day}" for day in range(start_day, tr_last+1)]
    catcols = ['id', 'item_id', 'dept_id', 'store_id', 'cat_id', 'state_id']
    dtype = {numcol:"float32" for numcol in numcols}
    dtype.update({col: "category" for col in catcols if col != "id"})
    dt = pd.read_csv("./sales_train_evaluation.csv", nrows = nrows, usecols = catcols + numcols, dtype = dtype)
    for col in catcols:
        if col != "id":
            dt[col] = dt[col].cat.codes.astype("int16")
            dt[col] -= dt[col].min()
    for day in range(tr_last+1, tr_last+28+1):
        dt[f"d_{day}"] = np.nan
    dt = pd.melt(dt,id_vars = catcols,value_vars = [col for col in dt.columns if col.startswith("d_")],var_name = "d",value_name = "sales")
    dt = dt.merge(cal, on= "d", copy = False)
    dt = dt.merge(prices, on = ["store_id", "item_id", "wm_yr_wk"], copy = False)
    return dt

# %%
# %%time
FIRST_DAY = 1
data = create_dt(first_day = FIRST_DAY)
# Out:
# CPU times: user 31.4 s, sys: 5.39 s, total: 36.8 s
# Wall time: 38.4 s

# %%
import math, decimal
dec = decimal.Decimal
def get_moon_phase(d):
    diff = d - datetime(2001, 1, 1)
    days = dec(diff.days) + (dec(diff.seconds) / dec(86400))
    lunations = dec("0.20439731") + (days * dec("0.03386319269"))
    phase_index = math.floor((lunations % dec(1) * dec(8)) + dec('0.5'))
    return int(phase_index) & 7

def create_fea(df):
    df.rename(columns={'sales':'demand'}, inplace=True)
    print('类别编码')
    icols = [['item_id', 'store_id']]
    for col in icols:
        col_name = '_'+'_'.join(col)+'_'
        df['enc'+col_name+'mean'] = df.groupby(col)['demand'].transform('mean').astype(np.float16)
        df['enc'+col_name+'std'] = df.groupby(col)['demand'].transform('std').astype(np.float16)
    print('lag特征')
    df['lag_t7'] = df.groupby(['id'])['demand'].transform(lambda x: x.shift(7)).astype(np.float16)
    df['lag_t14'] = df.groupby(['id'])['demand'].transform(lambda x: x.shift(14)).astype(np.float16)
    df['lag_t21'] = df.groupby(['id'])['demand'].transform(lambda x: x.shift(21)).astype(np.float16)
    df['lag_t28'] = df.groupby(['id'])['demand'].transform(lambda x: x.shift(28)).astype(np.float16)
    df['lag_t35'] = df.groupby(['id'])['demand'].transform(lambda x: x.shift(35)).astype(np.float16)
    print('rolling特征')
    for i in [7,14,21,28]:
        for j in [7,14,30,45,60]:
            df['rolling_mean'+str(i)+'_t'+str(j)] = df.groupby(['id'])['demand'].transform(lambda x: x.shift(i).rolling(j).mean()).astype(np.float16)
            if i == 28:
                df['rolling_std'+str(i)+'_t'+str(j)] = df.groupby(['id'])['demand'].transform(lambda x: x.shift(i).rolling(j).std()).astype(np.float16)
    df = df[(df.date >= '2016-04-25') | (pd.notna(df.rolling_mean28_t60))]
    print('处理时间')
    df['wday'] = getattr(df["date"].dt, 'dayofweek').astype("int8")
    df['mday'] = getattr(df["date"].dt, 'day').astype("int8")
    df['week'] = getattr(df["date"].dt, 'weekofyear').astype("int8")
    df['month'] = getattr(df["date"].dt, 'month').astype("int8")
    df['quarter'] = getattr(df["date"].dt, 'quarter').astype("int8")
    df['year'] = getattr(df["date"].dt, 'year').astype("int16")
    df['year'] = (df['year'] - df['year'].min()).astype("int8")
    df['week_month'] = df['mday'].apply(lambda x: ceil(x/7)).astype("int8")
    df['week_end'] = (df['wday'] >= 5).astype("int8")
    df['moon'] = df.date.apply(get_moon_phase)
    print('处理价格')
    df['price_max'] = df.groupby(['store_id','item_id'])['sell_price'].transform('max')
    df['price_min'] = df.groupby(['store_id','item_id'])['sell_price'].transform('min')
    df['price_std'] = df.groupby(['store_id','item_id'])['sell_price'].transform('std')
    df['price_mean'] = df.groupby(['store_id','item_id'])['sell_price'].transform('mean')
    df['price_median'] = df.groupby(['store_id', 'item_id'])['sell_price'].transform('median')
    df['price_dif'] = df['price_median'] - df['price_mean']
    df['price_norm'] = df['sell_price'] / df['price_max']
    df['price_nunique'] = df.groupby(['store_id', 'item_id'])['sell_price'].transform('nunique')
    df['item_nunique'] = df.groupby(['store_id', 'sell_price'])['item_id'].transform('nunique')
    df['price_momentum'] = df['sell_price'] / df.groupby(['store_id', 'item_id'])['sell_price'].transform(lambda x: x.shift(1))
    df['price_momentum_m'] = df['sell_price'] / df.groupby(['store_id', 'item_id', 'month'])['sell_price'].transform('mean')
    df['price_momentum_y'] = df['sell_price'] / df.groupby(['store_id', 'item_id', 'year'])['sell_price'].transform('mean')
    return df

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df
data = create_fea(data)
data = reduce_mem_usage(data)
# Out:
# 类别编码
# lag特征
# rolling特征
# 处理时间
# 处理价格
# Mem. usage decreased to 6535.15 Mb (25.5% reduction)

# %%
#data['sample_weight'] = np.log1p(1 / (data.groupby('id')['demand'].transform(lambda x: x.shift(28).diff().abs().expanding().mean()) + 1e-3))

# %%
ex_f = ['id', 'demand', 'sales', 'date', 'd', 'weekday', 'wm_yr_wk', 'state_id', 'store_id']
features = [i for i in data.columns if i not in ex_f]
cat_feats = ['item_id', 'dept_id', 'cat_id'] + ["event_name_1", "event_name_2", "event_type_1", "event_type_2"] + ['snap_CA', 'snap_WI', 'snap_TX']
all_features = features.copy()

# %%
import xgboost as xgb
def run_model(store_id, num_iter, data):
    df = data[data['store_id'] == store_id].copy()
    x_train = df[df['date'] <= '2016-04-24']
    y_train = x_train['demand']
    x_val = df[(df['date'] > '2016-04-24') & (df['date'] <= '2016-05-22')]
    y_val = x_val['demand']
    #fake_valid_inds = np.random.choice(len(x_train), 100000)
    #x_val = x_train.iloc[fake_valid_inds]
    #y_val = x_val['demand']
    train_set = xgb.DMatrix(x_train[features],label=y_train)
    val_set = xgb.DMatrix(x_val[features],label=y_val)
    watch_list = [(val_set, 'eval'), (train_set, 'train')]
    param = {'max_depth': 5, 'eta': 0.01, 'silent': 1, 'objective': 'reg:linear','num_boost_round':950,'subsample':0.8,'colsample_bytree':0.2319,'min_child_weight':11,'verbose_eval':20}
    model = xgb.train(param, train_set, num_boost_round=num_iter,early_stopping_rounds=100, evals=watch_list)
    return model

# %%
# def run_model(store_id, num_iter, data):
#     df = data[data['store_id'] == store_id].copy()
#     x_train = df[df['date'] <= '2016-04-24']
#     y_train = x_train['demand']
#     x_val = df[(df['date'] > '2016-04-24') & (df['date'] <= '2016-05-22')]
#     y_val = x_val['demand']
#     #fake_valid_inds = np.random.choice(len(x_train), 100000)
#     #x_val = x_train.iloc[fake_valid_inds]
#     #y_val = x_val['demand']
#     train_set = lgb.Dataset(x_train[features],y_train,categorical_feature=cat_feats,free_raw_data=False,weight=x_train['sample_weight'])
#     val_set = lgb.Dataset(x_val[features],y_val,categorical_feature=cat_feats,free_raw_data=False,weight=x_val['sample_weight'])
#     params = {
#             'boosting_type': 'gbdt',
#             'objective': 'tweedie',
#             'tweedie_variance_power': 1.1,
#             'metric': 'rmse',
#             'subsample': 0.85,
#             'subsample_freq': 1,
#             'learning_rate': 0.03,
#             'num_leaves': 2**11-1,
#             'min_data_in_leaf': 2**12-1,
#             'feature_fraction': 0.6,
#             'max_bin': 100,
#             'boost_from_average': False,
#             'verbose': -1,
#             'seed': 42
#           }
#     model = lgb.train(params, train_set, num_boost_round=num_iter, early_stopping_rounds=100, valid_sets=[train_set, val_set], verbose_eval=100)
#     return model

# %%
for i in range(10):
    print('Model', i+1)
    model_name = 'store_' + str(i) + '.sav'
    model = run_model(i, 2000, data)
    joblib.dump(model, model_name)
# Out:
# Model 1
# [0]	eval-rmse:3.72854	train-rmse:4.52034
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
# Will train until train-rmse hasn't improved in 100 rounds.
# [1]	eval-rmse:3.70446	train-rmse:4.49348
# [2]	eval-rmse:3.68204	train-rmse:4.4685
# [3]	eval-rmse:3.65997	train-rmse:4.44313
# [4]	eval-rmse:3.63896	train-rmse:4.41808
# [5]	eval-rmse:3.61782	train-rmse:4.3926
# [6]	eval-rmse:3.59606	train-rmse:4.36706
# [7]	eval-rmse:3.57337	train-rmse:4.34119
# [8]	eval-rmse:3.55212	train-rmse:4.31663
# [9]	eval-rmse:3.53124	train-rmse:4.29255
# [10]	eval-rmse:3.51051	train-rmse:4.26768
# [11]	eval-rmse:3.49022	train-rmse:4.24384
# [12]	eval-rmse:3.46989	train-rmse:4.2212
# [13]	eval-rmse:3.44915	train-rmse:4.19694
# [14]	eval-rmse:3.43056	train-rmse:4.17432
# [15]	eval-rmse:3.41094	train-rmse:4.15133
# [16]	eval-rmse:3.39329	train-rmse:4.12999
# [17]	eval-rmse:3.37507	train-rmse:4.1082
# [18]	eval-rmse:3.35673	train-rmse:4.08591
# [19]	eval-rmse:3.33882	train-rmse:4.06449
# [20]	eval-rmse:3.32115	train-rmse:4.04333
# [21]	eval-rmse:3.30376	train-rmse:4.0222
# [22]	eval-rmse:3.28668	train-rmse:4.00205
# [23]	eval-rmse:3.26884	train-rmse:3.98131
# [24]	eval-rmse:3.25278	train-rmse:3.96304
# [25]	eval-rmse:3.23598	train-rmse:3.94331
# [26]	eval-rmse:3.21844	train-rmse:3.92295
# [27]	eval-rmse:3.20143	train-rmse:3.90445
# [28]	eval-rmse:3.18457	train-rmse:3.88538
# [29]	eval-rmse:3.16832	train-rmse:3.86576
# [30]	eval-rmse:3.15219	train-rmse:3.84679
# [31]	eval-rmse:3.13696	train-rmse:3.82837
# [32]	eval-rmse:3.12117	train-rmse:3.81069
# [33]	eval-rmse:3.10508	train-rmse:3.79206
# [34]	eval-rmse:3.08961	train-rmse:3.77419
# [35]	eval-rmse:3.07396	train-rmse:3.75738
# [36]	eval-rmse:3.06054	train-rmse:3.74187
# [37]	eval-rmse:3.04646	train-rmse:3.72517
# [38]	eval-rmse:3.03297	train-rmse:3.70944
# [39]	eval-rmse:3.02035	train-rmse:3.69372
# [40]	eval-rmse:3.00745	train-rmse:3.67936
# [41]	eval-rmse:2.99347	train-rmse:3.66229
# [42]	eval-rmse:2.9797	train-rmse:3.64565
# [43]	eval-rmse:2.96607	train-rmse:3.62925
# [44]	eval-rmse:2.95311	train-rmse:3.61387
# [45]	eval-rmse:2.94009	train-rmse:3.59822
# [46]	eval-rmse:2.92726	train-rmse:3.58325
# [47]	eval-rmse:2.91395	train-rmse:3.56945
# [48]	eval-rmse:2.9013	train-rmse:3.55502
# [49]	eval-rmse:2.89017	train-rmse:3.54164
# [50]	eval-rmse:2.87906	train-rmse:3.52901
# [51]	eval-rmse:2.8682	train-rmse:3.51589
# [52]	eval-rmse:2.85644	train-rmse:3.50178
# [53]	eval-rmse:2.84468	train-rmse:3.48803
# [54]	eval-rmse:2.83288	train-rmse:3.47566
# [55]	eval-rmse:2.82164	train-rmse:3.46304
# [56]	eval-rmse:2.81032	train-rmse:3.4496
# [57]	eval-rmse:2.79931	train-rmse:3.43722
# [58]	eval-rmse:2.78794	train-rmse:3.42387
# [59]	eval-rmse:2.77749	train-rmse:3.41264
# [60]	eval-rmse:2.76701	train-rmse:3.40199
# [61]	eval-rmse:2.75661	train-rmse:3.38925
# [62]	eval-rmse:2.74696	train-rmse:3.37749
# [63]	eval-rmse:2.73718	train-rmse:3.36635
# [64]	eval-rmse:2.72777	train-rmse:3.35442
# [65]	eval-rmse:2.71931	train-rmse:3.34401
# [66]	eval-rmse:2.71085	train-rmse:3.33453
# [67]	eval-rmse:2.70178	train-rmse:3.32314
# [68]	eval-rmse:2.69266	train-rmse:3.31216
# [69]	eval-rmse:2.68415	train-rmse:3.30152
# [70]	eval-rmse:2.67507	train-rmse:3.2909
# [71]	eval-rmse:2.6662	train-rmse:3.28012
# [72]	eval-rmse:2.65772	train-rmse:3.26998
# [73]	eval-rmse:2.64894	train-rmse:3.25909
# [74]	eval-rmse:2.64026	train-rmse:3.24853
# [75]	eval-rmse:2.63283	train-rmse:3.23958
# [76]	eval-rmse:2.62424	train-rmse:3.22908
# [77]	eval-rmse:2.61621	train-rmse:3.21891
# [78]	eval-rmse:2.60853	train-rmse:3.21064
# [79]	eval-rmse:2.60052	train-rmse:3.20074
# [80]	eval-rmse:2.59339	train-rmse:3.19189
# [81]	eval-rmse:2.58533	train-rmse:3.18303
# [82]	eval-rmse:2.57836	train-rmse:3.17434
# [83]	eval-rmse:2.57168	train-rmse:3.16598
# [84]	eval-rmse:2.56483	train-rmse:3.15759
# [85]	eval-rmse:2.55749	train-rmse:3.14861
# [86]	eval-rmse:2.55113	train-rmse:3.14125
# [87]	eval-rmse:2.54486	train-rmse:3.13345
# [88]	eval-rmse:2.53748	train-rmse:3.12464
# [89]	eval-rmse:2.53046	train-rmse:3.11608
# [90]	eval-rmse:2.52385	train-rmse:3.10775
# [91]	eval-rmse:2.5179	train-rmse:3.10119
# [92]	eval-rmse:2.51178	train-rmse:3.09385
# [93]	eval-rmse:2.5053	train-rmse:3.08565
# [94]	eval-rmse:2.49885	train-rmse:3.0777
# [95]	eval-rmse:2.49327	train-rmse:3.07085
# [96]	eval-rmse:2.48698	train-rmse:3.06316
# [97]	eval-rmse:2.48137	train-rmse:3.05639
# [98]	eval-rmse:2.47547	train-rmse:3.04972
# [99]	eval-rmse:2.47091	train-rmse:3.04426
# [100]	eval-rmse:2.46494	train-rmse:3.03704
# [101]	eval-rmse:2.45957	train-rmse:3.03041
# [102]	eval-rmse:2.45365	train-rmse:3.02355
# [103]	eval-rmse:2.44777	train-rmse:3.01674
# [104]	eval-rmse:2.44229	train-rmse:3.01
# [105]	eval-rmse:2.4374	train-rmse:3.00371
# [106]	eval-rmse:2.4324	train-rmse:2.9976
# [107]	eval-rmse:2.4272	train-rmse:2.99111
# [108]	eval-rmse:2.4225	train-rmse:2.98589
# [109]	eval-rmse:2.41777	train-rmse:2.98015
# [110]	eval-rmse:2.41252	train-rmse:2.974
# [111]	eval-rmse:2.40753	train-rmse:2.96773
# [112]	eval-rmse:2.403	train-rmse:2.9622
# [113]	eval-rmse:2.39795	train-rmse:2.95627
# [114]	eval-rmse:2.39377	train-rmse:2.95091
# [115]	eval-rmse:2.38907	train-rmse:2.94518
# [116]	eval-rmse:2.38464	train-rmse:2.93958
# [117]	eval-rmse:2.38064	train-rmse:2.9352
# [118]	eval-rmse:2.37669	train-rmse:2.9302
# [119]	eval-rmse:2.37231	train-rmse:2.92526
# [120]	eval-rmse:2.36812	train-rmse:2.92035
# [121]	eval-rmse:2.36402	train-rmse:2.91565
# [122]	eval-rmse:2.36039	train-rmse:2.91163
# [123]	eval-rmse:2.35689	train-rmse:2.90724
# [124]	eval-rmse:2.35282	train-rmse:2.90269
# [125]	eval-rmse:2.34882	train-rmse:2.89838
# [126]	eval-rmse:2.34529	train-rmse:2.89451
# [127]	eval-rmse:2.34175	train-rmse:2.89018
# [128]	eval-rmse:2.3381	train-rmse:2.88592
# [129]	eval-rmse:2.33429	train-rmse:2.88101
# [130]	eval-rmse:2.33043	train-rmse:2.87616
# [131]	eval-rmse:2.32693	train-rmse:2.87202
# [132]	eval-rmse:2.32345	train-rmse:2.86803
# [133]	eval-rmse:2.32008	train-rmse:2.86347
# [134]	eval-rmse:2.31659	train-rmse:2.85921
# [135]	eval-rmse:2.31373	train-rmse:2.85554
# [136]	eval-rmse:2.31093	train-rmse:2.85184
# [137]	eval-rmse:2.30745	train-rmse:2.84758
# [138]	eval-rmse:2.30421	train-rmse:2.84385
# [139]	eval-rmse:2.30104	train-rmse:2.83974
# [140]	eval-rmse:2.29801	train-rmse:2.83601
# [141]	eval-rmse:2.29544	train-rmse:2.83274
# [142]	eval-rmse:2.29306	train-rmse:2.82995
# [143]	eval-rmse:2.29022	train-rmse:2.82646
# [144]	eval-rmse:2.28733	train-rmse:2.82306
# [145]	eval-rmse:2.28456	train-rmse:2.81969
# [146]	eval-rmse:2.28213	train-rmse:2.81657
# [147]	eval-rmse:2.27952	train-rmse:2.81345
# [148]	eval-rmse:2.27672	train-rmse:2.8099
# [149]	eval-rmse:2.27442	train-rmse:2.80704
# [150]	eval-rmse:2.27211	train-rmse:2.80418
# [151]	eval-rmse:2.26937	train-rmse:2.80121
# [152]	eval-rmse:2.26713	train-rmse:2.79836
# [153]	eval-rmse:2.26458	train-rmse:2.79565
# [154]	eval-rmse:2.26205	train-rmse:2.79234
# [155]	eval-rmse:2.25934	train-rmse:2.78904
# [156]	eval-rmse:2.25712	train-rmse:2.78629
# [157]	eval-rmse:2.25459	train-rmse:2.78305
# [158]	eval-rmse:2.25266	train-rmse:2.78055
# [159]	eval-rmse:2.25086	train-rmse:2.77855
# [160]	eval-rmse:2.24875	train-rmse:2.77612
# [161]	eval-rmse:2.24699	train-rmse:2.77382
# [162]	eval-rmse:2.24466	train-rmse:2.7707
# [163]	eval-rmse:2.24263	train-rmse:2.7682
# [164]	eval-rmse:2.24076	train-rmse:2.76566
# [165]	eval-rmse:2.23833	train-rmse:2.76278
# [166]	eval-rmse:2.23676	train-rmse:2.76106
# [167]	eval-rmse:2.23515	train-rmse:2.75889
# [168]	eval-rmse:2.23337	train-rmse:2.75666
# [169]	eval-rmse:2.23176	train-rmse:2.75424
# [170]	eval-rmse:2.22997	train-rmse:2.75195
# [171]	eval-rmse:2.2278	train-rmse:2.7492
# [172]	eval-rmse:2.22603	train-rmse:2.74686
# [173]	eval-rmse:2.22387	train-rmse:2.7446
# [174]	eval-rmse:2.22221	train-rmse:2.74234
# [175]	eval-rmse:2.22081	train-rmse:2.74006
# [176]	eval-rmse:2.21899	train-rmse:2.73773
# [177]	eval-rmse:2.21716	train-rmse:2.73536
# [178]	eval-rmse:2.21573	train-rmse:2.73329
# [179]	eval-rmse:2.21403	train-rmse:2.73134
# [180]	eval-rmse:2.21266	train-rmse:2.72935
# [181]	eval-rmse:2.21143	train-rmse:2.72797
# [182]	eval-rmse:2.20988	train-rmse:2.72625
# [183]	eval-rmse:2.20857	train-rmse:2.72449
# [184]	eval-rmse:2.20725	train-rmse:2.72284
# [185]	eval-rmse:2.20559	train-rmse:2.7208
# [186]	eval-rmse:2.20397	train-rmse:2.71908
# [187]	eval-rmse:2.20261	train-rmse:2.71735
# [188]	eval-rmse:2.20127	train-rmse:2.71559
# [189]	eval-rmse:2.19977	train-rmse:2.71352
# [190]	eval-rmse:2.19854	train-rmse:2.71206
# [191]	eval-rmse:2.19722	train-rmse:2.71052
# [192]	eval-rmse:2.19589	train-rmse:2.70871
# [193]	eval-rmse:2.1945	train-rmse:2.70715
# [194]	eval-rmse:2.19315	train-rmse:2.7056
# [195]	eval-rmse:2.19192	train-rmse:2.70403
# [196]	eval-rmse:2.19068	train-rmse:2.70242
# [197]	eval-rmse:2.18959	train-rmse:2.70117
# [198]	eval-rmse:2.18855	train-rmse:2.70006
# [199]	eval-rmse:2.18758	train-rmse:2.69861
# [200]	eval-rmse:2.1863	train-rmse:2.69712
# [201]	eval-rmse:2.18526	train-rmse:2.69569
# [202]	eval-rmse:2.18399	train-rmse:2.69393
# [203]	eval-rmse:2.18265	train-rmse:2.69231
# [204]	eval-rmse:2.18146	train-rmse:2.6906
# [205]	eval-rmse:2.18061	train-rmse:2.68942
# [206]	eval-rmse:2.17941	train-rmse:2.68773
# [207]	eval-rmse:2.17831	train-rmse:2.68623
# [208]	eval-rmse:2.17732	train-rmse:2.68493
# [209]	eval-rmse:2.17624	train-rmse:2.68386
# [210]	eval-rmse:2.17505	train-rmse:2.68237
# [211]	eval-rmse:2.17389	train-rmse:2.68093
# [212]	eval-rmse:2.17313	train-rmse:2.6801
# [213]	eval-rmse:2.17205	train-rmse:2.67907
# [214]	eval-rmse:2.17135	train-rmse:2.67823
# [215]	eval-rmse:2.17035	train-rmse:2.67673
# [216]	eval-rmse:2.16924	train-rmse:2.67541
# [217]	eval-rmse:2.1684	train-rmse:2.67431
# [218]	eval-rmse:2.16741	train-rmse:2.673
# [219]	eval-rmse:2.16634	train-rmse:2.67153
# [220]	eval-rmse:2.16529	train-rmse:2.67001
# [221]	eval-rmse:2.16453	train-rmse:2.6691
# [222]	eval-rmse:2.16363	train-rmse:2.66779
# [223]	eval-rmse:2.16265	train-rmse:2.66635
# [224]	eval-rmse:2.16183	train-rmse:2.6653
# [225]	eval-rmse:2.16129	train-rmse:2.66465
# [226]	eval-rmse:2.16054	train-rmse:2.66389
# [227]	eval-rmse:2.15957	train-rmse:2.66266
# [228]	eval-rmse:2.15898	train-rmse:2.66191
# [229]	eval-rmse:2.15815	train-rmse:2.66085
# [230]	eval-rmse:2.15751	train-rmse:2.65973
# [231]	eval-rmse:2.15682	train-rmse:2.65884
# [232]	eval-rmse:2.15607	train-rmse:2.65769
# [233]	eval-rmse:2.15534	train-rmse:2.65674
# [234]	eval-rmse:2.15464	train-rmse:2.65593
# [235]	eval-rmse:2.15389	train-rmse:2.65483
# [236]	eval-rmse:2.15317	train-rmse:2.65376
# [237]	eval-rmse:2.15262	train-rmse:2.65266
# [238]	eval-rmse:2.15179	train-rmse:2.65152
# [239]	eval-rmse:2.15115	train-rmse:2.65068
# [240]	eval-rmse:2.15053	train-rmse:2.64984
# [241]	eval-rmse:2.14963	train-rmse:2.64871
# [242]	eval-rmse:2.14902	train-rmse:2.64808
# [243]	eval-rmse:2.14847	train-rmse:2.64723
# [244]	eval-rmse:2.14789	train-rmse:2.64642
# [245]	eval-rmse:2.1472	train-rmse:2.6458
# [246]	eval-rmse:2.14662	train-rmse:2.6452
# [247]	eval-rmse:2.14602	train-rmse:2.64428
# [248]	eval-rmse:2.1455	train-rmse:2.6434
# [249]	eval-rmse:2.14496	train-rmse:2.64264
# [250]	eval-rmse:2.1443	train-rmse:2.64173
# [251]	eval-rmse:2.14366	train-rmse:2.64085
# [252]	eval-rmse:2.14317	train-rmse:2.64028
# [253]	eval-rmse:2.14264	train-rmse:2.63947
# [254]	eval-rmse:2.14205	train-rmse:2.63851
# [255]	eval-rmse:2.14145	train-rmse:2.63755
# [256]	eval-rmse:2.14095	train-rmse:2.6369
# [257]	eval-rmse:2.14036	train-rmse:2.63612
# [258]	eval-rmse:2.13996	train-rmse:2.63535
# [259]	eval-rmse:2.13966	train-rmse:2.63487
# [260]	eval-rmse:2.13918	train-rmse:2.63413
# [261]	eval-rmse:2.1387	train-rmse:2.6334
# [262]	eval-rmse:2.13828	train-rmse:2.63272
# [263]	eval-rmse:2.13781	train-rmse:2.63211
# [264]	eval-rmse:2.1374	train-rmse:2.6314
# [265]	eval-rmse:2.1369	train-rmse:2.63084
# [266]	eval-rmse:2.13632	train-rmse:2.63003
# [267]	eval-rmse:2.13578	train-rmse:2.62924
# [268]	eval-rmse:2.13533	train-rmse:2.62867
# [269]	eval-rmse:2.13497	train-rmse:2.62803
# [270]	eval-rmse:2.13447	train-rmse:2.6274
# [271]	eval-rmse:2.1341	train-rmse:2.62685
# [272]	eval-rmse:2.13388	train-rmse:2.62651
# [273]	eval-rmse:2.13337	train-rmse:2.6257
# [274]	eval-rmse:2.13299	train-rmse:2.62496
# [275]	eval-rmse:2.13269	train-rmse:2.62459
# [276]	eval-rmse:2.13246	train-rmse:2.62423
# [277]	eval-rmse:2.13214	train-rmse:2.6238
# [278]	eval-rmse:2.13178	train-rmse:2.62327
# [279]	eval-rmse:2.13142	train-rmse:2.62259
# [280]	eval-rmse:2.13098	train-rmse:2.62196
# [281]	eval-rmse:2.13056	train-rmse:2.62154
# [282]	eval-rmse:2.13014	train-rmse:2.6209
# [283]	eval-rmse:2.12973	train-rmse:2.62024
# [284]	eval-rmse:2.12945	train-rmse:2.61978
# [285]	eval-rmse:2.12902	train-rmse:2.61919
# [286]	eval-rmse:2.12881	train-rmse:2.61845
# [287]	eval-rmse:2.12837	train-rmse:2.61786
# [288]	eval-rmse:2.12805	train-rmse:2.61734
# [289]	eval-rmse:2.12772	train-rmse:2.61692
# [290]	eval-rmse:2.12738	train-rmse:2.61649
# [291]	eval-rmse:2.12709	train-rmse:2.61604
# [292]	eval-rmse:2.12672	train-rmse:2.61545
# [293]	eval-rmse:2.12657	train-rmse:2.61501
# [294]	eval-rmse:2.12619	train-rmse:2.61428
# [295]	eval-rmse:2.12585	train-rmse:2.6139
# [296]	eval-rmse:2.12563	train-rmse:2.61353
# [297]	eval-rmse:2.12546	train-rmse:2.61304
# [298]	eval-rmse:2.12512	train-rmse:2.6125
# [299]	eval-rmse:2.12479	train-rmse:2.61187
# [300]	eval-rmse:2.12457	train-rmse:2.61148
# [301]	eval-rmse:2.12424	train-rmse:2.611
# [302]	eval-rmse:2.1241	train-rmse:2.61063
# [303]	eval-rmse:2.12387	train-rmse:2.61025
# [304]	eval-rmse:2.12361	train-rmse:2.60994
# [305]	eval-rmse:2.12332	train-rmse:2.60938
# [306]	eval-rmse:2.12316	train-rmse:2.60899
# [307]	eval-rmse:2.12284	train-rmse:2.60852
# [308]	eval-rmse:2.12254	train-rmse:2.60825
# [309]	eval-rmse:2.12239	train-rmse:2.6078
# [310]	eval-rmse:2.12209	train-rmse:2.60731
# [311]	eval-rmse:2.12183	train-rmse:2.6068
# [312]	eval-rmse:2.1215	train-rmse:2.60629
# [313]	eval-rmse:2.12136	train-rmse:2.60578
# [314]	eval-rmse:2.12116	train-rmse:2.60546
# [315]	eval-rmse:2.12102	train-rmse:2.60505
# [316]	eval-rmse:2.12092	train-rmse:2.60465
# [317]	eval-rmse:2.12069	train-rmse:2.60428
# [318]	eval-rmse:2.12063	train-rmse:2.60403
# [319]	eval-rmse:2.12044	train-rmse:2.60367
# [320]	eval-rmse:2.12035	train-rmse:2.60343
# [321]	eval-rmse:2.12013	train-rmse:2.60315
# [322]	eval-rmse:2.11989	train-rmse:2.60272
# [323]	eval-rmse:2.11973	train-rmse:2.60246
# [324]	eval-rmse:2.11944	train-rmse:2.60196
# [325]	eval-rmse:2.11921	train-rmse:2.60165
# [326]	eval-rmse:2.11907	train-rmse:2.6013
# [327]	eval-rmse:2.11878	train-rmse:2.60098
# [328]	eval-rmse:2.11857	train-rmse:2.6007
# [329]	eval-rmse:2.11835	train-rmse:2.6002
# [330]	eval-rmse:2.11807	train-rmse:2.59977
# [331]	eval-rmse:2.11786	train-rmse:2.5995
# [332]	eval-rmse:2.11762	train-rmse:2.59915
# [333]	eval-rmse:2.11749	train-rmse:2.59882
# [334]	eval-rmse:2.1174	train-rmse:2.59863
# [335]	eval-rmse:2.11716	train-rmse:2.59822
# [336]	eval-rmse:2.11707	train-rmse:2.59778
# [337]	eval-rmse:2.11707	train-rmse:2.59744
# [338]	eval-rmse:2.11685	train-rmse:2.59718
# [339]	eval-rmse:2.11667	train-rmse:2.59695
# [340]	eval-rmse:2.11646	train-rmse:2.59649
# [341]	eval-rmse:2.11624	train-rmse:2.59627
# [342]	eval-rmse:2.11612	train-rmse:2.5961
# [343]	eval-rmse:2.11591	train-rmse:2.59569
# [344]	eval-rmse:2.11572	train-rmse:2.59534
# [345]	eval-rmse:2.11557	train-rmse:2.59507
# [346]	eval-rmse:2.11547	train-rmse:2.59474
# [347]	eval-rmse:2.11532	train-rmse:2.5945
# [348]	eval-rmse:2.11521	train-rmse:2.59414
# [349]	eval-rmse:2.11497	train-rmse:2.59383
# [350]	eval-rmse:2.1148	train-rmse:2.59356
# [351]	eval-rmse:2.11464	train-rmse:2.59327
# [352]	eval-rmse:2.11455	train-rmse:2.593
# [353]	eval-rmse:2.11441	train-rmse:2.59262
# [354]	eval-rmse:2.11425	train-rmse:2.59223
# [355]	eval-rmse:2.11415	train-rmse:2.59203
# [356]	eval-rmse:2.11392	train-rmse:2.59178
# [357]	eval-rmse:2.11385	train-rmse:2.59162
# [358]	eval-rmse:2.11381	train-rmse:2.59148
# [359]	eval-rmse:2.11369	train-rmse:2.59129
# [360]	eval-rmse:2.11355	train-rmse:2.59091
# [361]	eval-rmse:2.11338	train-rmse:2.59054
# [362]	eval-rmse:2.11329	train-rmse:2.59021
# [363]	eval-rmse:2.11316	train-rmse:2.5899
# [364]	eval-rmse:2.11302	train-rmse:2.58964
# [365]	eval-rmse:2.11288	train-rmse:2.58935
# [366]	eval-rmse:2.11274	train-rmse:2.58911
# [367]	eval-rmse:2.11255	train-rmse:2.58879
# [368]	eval-rmse:2.11238	train-rmse:2.58857
# [369]	eval-rmse:2.11224	train-rmse:2.58821
# [370]	eval-rmse:2.11216	train-rmse:2.58783
# [371]	eval-rmse:2.11198	train-rmse:2.58761
# [372]	eval-rmse:2.11175	train-rmse:2.58723
# [373]	eval-rmse:2.11155	train-rmse:2.5869
# [374]	eval-rmse:2.11139	train-rmse:2.58656
# [375]	eval-rmse:2.11137	train-rmse:2.58643
# [376]	eval-rmse:2.11124	train-rmse:2.58625
# [377]	eval-rmse:2.11106	train-rmse:2.58599
# [378]	eval-rmse:2.11095	train-rmse:2.58572
# [379]	eval-rmse:2.11084	train-rmse:2.58553
# [380]	eval-rmse:2.11065	train-rmse:2.58526
# [381]	eval-rmse:2.11056	train-rmse:2.58504
# [382]	eval-rmse:2.11057	train-rmse:2.58483
# [383]	eval-rmse:2.11048	train-rmse:2.58456
# [384]	eval-rmse:2.11039	train-rmse:2.58442
# [385]	eval-rmse:2.11028	train-rmse:2.58424
# [386]	eval-rmse:2.11027	train-rmse:2.584
# [387]	eval-rmse:2.1101	train-rmse:2.5837
# [388]	eval-rmse:2.11004	train-rmse:2.58352
# [389]	eval-rmse:2.10999	train-rmse:2.58337
# [390]	eval-rmse:2.10993	train-rmse:2.58308
# [391]	eval-rmse:2.1098	train-rmse:2.58285
# [392]	eval-rmse:2.10978	train-rmse:2.58246
# [393]	eval-rmse:2.10968	train-rmse:2.58229
# [394]	eval-rmse:2.10961	train-rmse:2.58209
# [395]	eval-rmse:2.1096	train-rmse:2.5819
# [396]	eval-rmse:2.10954	train-rmse:2.58171
# [397]	eval-rmse:2.10951	train-rmse:2.58155
# [398]	eval-rmse:2.10937	train-rmse:2.58131
# [399]	eval-rmse:2.10924	train-rmse:2.58099
# [400]	eval-rmse:2.10915	train-rmse:2.58083
# [401]	eval-rmse:2.1091	train-rmse:2.58071
# [402]	eval-rmse:2.10905	train-rmse:2.58054
# [403]	eval-rmse:2.109	train-rmse:2.58039
# [404]	eval-rmse:2.10888	train-rmse:2.58024
# [405]	eval-rmse:2.1088	train-rmse:2.58008
# [406]	eval-rmse:2.10872	train-rmse:2.57965
# [407]	eval-rmse:2.1087	train-rmse:2.57944
# [408]	eval-rmse:2.10859	train-rmse:2.57925
# [409]	eval-rmse:2.10848	train-rmse:2.57905
# [410]	eval-rmse:2.10836	train-rmse:2.57888
# [411]	eval-rmse:2.10827	train-rmse:2.57873
# [412]	eval-rmse:2.10819	train-rmse:2.57853
# [413]	eval-rmse:2.1081	train-rmse:2.57823
# [414]	eval-rmse:2.1081	train-rmse:2.57799
# [415]	eval-rmse:2.10807	train-rmse:2.57785
# [416]	eval-rmse:2.10796	train-rmse:2.57764
# [417]	eval-rmse:2.10784	train-rmse:2.57739
# [418]	eval-rmse:2.10774	train-rmse:2.57721
# [419]	eval-rmse:2.10762	train-rmse:2.57705
# [420]	eval-rmse:2.10755	train-rmse:2.57696
# [421]	eval-rmse:2.10745	train-rmse:2.57681
# [422]	eval-rmse:2.1074	train-rmse:2.57661
# [423]	eval-rmse:2.10736	train-rmse:2.57652
# [424]	eval-rmse:2.10728	train-rmse:2.57624
# [425]	eval-rmse:2.10721	train-rmse:2.57614
# [426]	eval-rmse:2.10715	train-rmse:2.57601
# [427]	eval-rmse:2.10709	train-rmse:2.57581
# [428]	eval-rmse:2.10697	train-rmse:2.57563
# [429]	eval-rmse:2.10691	train-rmse:2.5755
# [430]	eval-rmse:2.10688	train-rmse:2.57526
# [431]	eval-rmse:2.10677	train-rmse:2.57497
# [432]	eval-rmse:2.1067	train-rmse:2.57478
# [433]	eval-rmse:2.10666	train-rmse:2.57466
# [434]	eval-rmse:2.10661	train-rmse:2.57452
# [435]	eval-rmse:2.10652	train-rmse:2.57435
# [436]	eval-rmse:2.1064	train-rmse:2.57409
# [437]	eval-rmse:2.10629	train-rmse:2.57386
# [438]	eval-rmse:2.10626	train-rmse:2.5736
# [439]	eval-rmse:2.10621	train-rmse:2.57348
# [440]	eval-rmse:2.10613	train-rmse:2.5732
# [441]	eval-rmse:2.10606	train-rmse:2.573
# [442]	eval-rmse:2.10598	train-rmse:2.57287
# [443]	eval-rmse:2.10595	train-rmse:2.57274
# [444]	eval-rmse:2.10589	train-rmse:2.57252
# [445]	eval-rmse:2.10586	train-rmse:2.57241
# [446]	eval-rmse:2.1058	train-rmse:2.57221
# [447]	eval-rmse:2.10576	train-rmse:2.57211
# [448]	eval-rmse:2.10571	train-rmse:2.57198
# [449]	eval-rmse:2.10562	train-rmse:2.57179
# [450]	eval-rmse:2.1055	train-rmse:2.57163
# [451]	eval-rmse:2.10545	train-rmse:2.5715
# [452]	eval-rmse:2.10533	train-rmse:2.57127
# [453]	eval-rmse:2.10533	train-rmse:2.57095
# [454]	eval-rmse:2.10524	train-rmse:2.57083
# [455]	eval-rmse:2.1052	train-rmse:2.57067
# [456]	eval-rmse:2.10515	train-rmse:2.57042
# [457]	eval-rmse:2.1051	train-rmse:2.57032
# [458]	eval-rmse:2.10504	train-rmse:2.57017
# [459]	eval-rmse:2.10499	train-rmse:2.57007
# [460]	eval-rmse:2.105	train-rmse:2.56993
# [461]	eval-rmse:2.10495	train-rmse:2.56984
# [462]	eval-rmse:2.10487	train-rmse:2.56962
# [463]	eval-rmse:2.1048	train-rmse:2.56947
# [464]	eval-rmse:2.10476	train-rmse:2.56931
# [465]	eval-rmse:2.10473	train-rmse:2.56922
# [466]	eval-rmse:2.1047	train-rmse:2.56912
# [467]	eval-rmse:2.10464	train-rmse:2.56902
# [468]	eval-rmse:2.10462	train-rmse:2.56887
# [469]	eval-rmse:2.10458	train-rmse:2.56877
# [470]	eval-rmse:2.10453	train-rmse:2.56868
# [471]	eval-rmse:2.10451	train-rmse:2.56841
# [472]	eval-rmse:2.10441	train-rmse:2.56826
# [473]	eval-rmse:2.10436	train-rmse:2.56807
# [474]	eval-rmse:2.10429	train-rmse:2.56793
# [475]	eval-rmse:2.10427	train-rmse:2.56779
# [476]	eval-rmse:2.10419	train-rmse:2.56766
# [477]	eval-rmse:2.10424	train-rmse:2.56751
# [478]	eval-rmse:2.10419	train-rmse:2.56741
# [479]	eval-rmse:2.10411	train-rmse:2.56725
# [480]	eval-rmse:2.10408	train-rmse:2.5671
# [481]	eval-rmse:2.10405	train-rmse:2.56697
# [482]	eval-rmse:2.10399	train-rmse:2.56683
# [483]	eval-rmse:2.10402	train-rmse:2.56674
# [484]	eval-rmse:2.10403	train-rmse:2.56662
# [485]	eval-rmse:2.10398	train-rmse:2.56633
# [486]	eval-rmse:2.10395	train-rmse:2.56624
# [487]	eval-rmse:2.10387	train-rmse:2.56613
# [488]	eval-rmse:2.10385	train-rmse:2.56593
# [489]	eval-rmse:2.10378	train-rmse:2.56577
# [490]	eval-rmse:2.10373	train-rmse:2.56566
# [491]	eval-rmse:2.10371	train-rmse:2.56553
# [492]	eval-rmse:2.10368	train-rmse:2.56544
# [493]	eval-rmse:2.10359	train-rmse:2.56531
# [494]	eval-rmse:2.10353	train-rmse:2.56523
# [495]	eval-rmse:2.10347	train-rmse:2.56507
# [496]	eval-rmse:2.10345	train-rmse:2.56497
# [497]	eval-rmse:2.10342	train-rmse:2.56482
# [498]	eval-rmse:2.10339	train-rmse:2.56471
# [499]	eval-rmse:2.10334	train-rmse:2.56446
# [500]	eval-rmse:2.10328	train-rmse:2.56436
# [501]	eval-rmse:2.10319	train-rmse:2.56425
# [502]	eval-rmse:2.10313	train-rmse:2.56419
# [503]	eval-rmse:2.1031	train-rmse:2.56403
# [504]	eval-rmse:2.10303	train-rmse:2.56386
# [505]	eval-rmse:2.103	train-rmse:2.56377
# [506]	eval-rmse:2.10302	train-rmse:2.5636
# [507]	eval-rmse:2.10296	train-rmse:2.56343
# [508]	eval-rmse:2.10301	train-rmse:2.5633
# [509]	eval-rmse:2.10296	train-rmse:2.56322
# [510]	eval-rmse:2.10289	train-rmse:2.56313
# [511]	eval-rmse:2.10288	train-rmse:2.56287
# [512]	eval-rmse:2.10284	train-rmse:2.56278
# [513]	eval-rmse:2.10278	train-rmse:2.56264
# [514]	eval-rmse:2.10278	train-rmse:2.56238
# [515]	eval-rmse:2.10274	train-rmse:2.56213
# [516]	eval-rmse:2.10268	train-rmse:2.56187
# [517]	eval-rmse:2.10267	train-rmse:2.56172
# [518]	eval-rmse:2.10268	train-rmse:2.56154
# [519]	eval-rmse:2.10264	train-rmse:2.56135
# [520]	eval-rmse:2.10259	train-rmse:2.56124
# [521]	eval-rmse:2.10261	train-rmse:2.5609
# [522]	eval-rmse:2.10256	train-rmse:2.5608
# [523]	eval-rmse:2.10254	train-rmse:2.56066
# [524]	eval-rmse:2.10249	train-rmse:2.56053
# [525]	eval-rmse:2.10243	train-rmse:2.5604
# [526]	eval-rmse:2.10242	train-rmse:2.56021
# [527]	eval-rmse:2.10236	train-rmse:2.56012
# [528]	eval-rmse:2.10236	train-rmse:2.55998
# [529]	eval-rmse:2.1023	train-rmse:2.55984
# [530]	eval-rmse:2.10224	train-rmse:2.55965
# [531]	eval-rmse:2.10215	train-rmse:2.55952
# [532]	eval-rmse:2.10213	train-rmse:2.55945
# [533]	eval-rmse:2.10211	train-rmse:2.55934
# [534]	eval-rmse:2.10207	train-rmse:2.55918
# [535]	eval-rmse:2.10199	train-rmse:2.55909
# [536]	eval-rmse:2.10193	train-rmse:2.55899
# [537]	eval-rmse:2.10196	train-rmse:2.55877
# [538]	eval-rmse:2.10194	train-rmse:2.55866
# [539]	eval-rmse:2.10191	train-rmse:2.55856
# [540]	eval-rmse:2.10184	train-rmse:2.55837
# [541]	eval-rmse:2.10185	train-rmse:2.55808
# [542]	eval-rmse:2.10189	train-rmse:2.558
# [543]	eval-rmse:2.10187	train-rmse:2.55787
# [544]	eval-rmse:2.10184	train-rmse:2.55773
# [545]	eval-rmse:2.10181	train-rmse:2.5576
# [546]	eval-rmse:2.10177	train-rmse:2.55748
# [547]	eval-rmse:2.10172	train-rmse:2.55736
# [548]	eval-rmse:2.10167	train-rmse:2.55728
# [549]	eval-rmse:2.10164	train-rmse:2.55712
# [550]	eval-rmse:2.10157	train-rmse:2.55701
# [551]	eval-rmse:2.10153	train-rmse:2.55689
# [552]	eval-rmse:2.1015	train-rmse:2.55677
# [553]	eval-rmse:2.10146	train-rmse:2.55652
# [554]	eval-rmse:2.10141	train-rmse:2.55636
# [555]	eval-rmse:2.10139	train-rmse:2.55626
# [556]	eval-rmse:2.10136	train-rmse:2.55612
# [557]	eval-rmse:2.10133	train-rmse:2.55597
# [558]	eval-rmse:2.10131	train-rmse:2.55571
# [559]	eval-rmse:2.10131	train-rmse:2.55555
# [560]	eval-rmse:2.10125	train-rmse:2.5554
# [561]	eval-rmse:2.10119	train-rmse:2.55533
# [562]	eval-rmse:2.10114	train-rmse:2.55525
# [563]	eval-rmse:2.10114	train-rmse:2.55518
# [564]	eval-rmse:2.10117	train-rmse:2.55484
# [565]	eval-rmse:2.10113	train-rmse:2.5547
# [566]	eval-rmse:2.1011	train-rmse:2.55459
# [567]	eval-rmse:2.10108	train-rmse:2.55448
# [568]	eval-rmse:2.10108	train-rmse:2.55421
# [569]	eval-rmse:2.10098	train-rmse:2.55406
# [570]	eval-rmse:2.10095	train-rmse:2.55388
# [571]	eval-rmse:2.10091	train-rmse:2.55377
# [572]	eval-rmse:2.10088	train-rmse:2.55369
# [573]	eval-rmse:2.10093	train-rmse:2.55356
# [574]	eval-rmse:2.10092	train-rmse:2.55348
# [575]	eval-rmse:2.1009	train-rmse:2.5533
# [576]	eval-rmse:2.10087	train-rmse:2.55309
# [577]	eval-rmse:2.10085	train-rmse:2.55299
# [578]	eval-rmse:2.10085	train-rmse:2.55284
# [579]	eval-rmse:2.10083	train-rmse:2.55249
# [580]	eval-rmse:2.10081	train-rmse:2.55233
# [581]	eval-rmse:2.10078	train-rmse:2.5522
# [582]	eval-rmse:2.10075	train-rmse:2.55209
# [583]	eval-rmse:2.10072	train-rmse:2.552
# [584]	eval-rmse:2.10073	train-rmse:2.55181
# [585]	eval-rmse:2.10066	train-rmse:2.55171
# [586]	eval-rmse:2.10062	train-rmse:2.5516
# [587]	eval-rmse:2.1006	train-rmse:2.55147
# [588]	eval-rmse:2.10055	train-rmse:2.55131
# [589]	eval-rmse:2.1005	train-rmse:2.5512
# [590]	eval-rmse:2.10048	train-rmse:2.55109
# [591]	eval-rmse:2.10047	train-rmse:2.55098
# [592]	eval-rmse:2.10045	train-rmse:2.55081
# [593]	eval-rmse:2.10043	train-rmse:2.55073
# [594]	eval-rmse:2.10041	train-rmse:2.55064
# [595]	eval-rmse:2.10041	train-rmse:2.5505
# [596]	eval-rmse:2.10041	train-rmse:2.55042
# [597]	eval-rmse:2.10038	train-rmse:2.55028
# [598]	eval-rmse:2.10035	train-rmse:2.55022
# [599]	eval-rmse:2.10039	train-rmse:2.5501
# [600]	eval-rmse:2.10034	train-rmse:2.54998
# [601]	eval-rmse:2.10028	train-rmse:2.5499
# [602]	eval-rmse:2.10027	train-rmse:2.54984
# [603]	eval-rmse:2.10028	train-rmse:2.54969
# [604]	eval-rmse:2.10024	train-rmse:2.5496
# [605]	eval-rmse:2.10022	train-rmse:2.54949
# [606]	eval-rmse:2.10021	train-rmse:2.5494
# [607]	eval-rmse:2.1002	train-rmse:2.54928
# [608]	eval-rmse:2.1002	train-rmse:2.54916
# [609]	eval-rmse:2.1002	train-rmse:2.54898
# [610]	eval-rmse:2.10019	train-rmse:2.5489
# [611]	eval-rmse:2.10017	train-rmse:2.54875
# [612]	eval-rmse:2.10013	train-rmse:2.54852
# [613]	eval-rmse:2.10014	train-rmse:2.54842
# [614]	eval-rmse:2.10012	train-rmse:2.54832
# [615]	eval-rmse:2.10003	train-rmse:2.54822
# [616]	eval-rmse:2.10004	train-rmse:2.54803
# [617]	eval-rmse:2.10003	train-rmse:2.54794
# [618]	eval-rmse:2.10002	train-rmse:2.54786
# [619]	eval-rmse:2.10002	train-rmse:2.54777
# [620]	eval-rmse:2.10001	train-rmse:2.54767
# [621]	eval-rmse:2.09996	train-rmse:2.54748
# [622]	eval-rmse:2.09993	train-rmse:2.54739
# [623]	eval-rmse:2.09992	train-rmse:2.54724
# [624]	eval-rmse:2.0999	train-rmse:2.54714
# [625]	eval-rmse:2.09988	train-rmse:2.54698
# [626]	eval-rmse:2.09988	train-rmse:2.54692
# [627]	eval-rmse:2.09984	train-rmse:2.54679
# [628]	eval-rmse:2.09979	train-rmse:2.54661
# [629]	eval-rmse:2.09978	train-rmse:2.54653
# [630]	eval-rmse:2.0998	train-rmse:2.5463
# [631]	eval-rmse:2.09976	train-rmse:2.54623
# [632]	eval-rmse:2.09973	train-rmse:2.5461
# [633]	eval-rmse:2.09968	train-rmse:2.54603
# [634]	eval-rmse:2.09967	train-rmse:2.54588
# [635]	eval-rmse:2.09963	train-rmse:2.54576
# [636]	eval-rmse:2.0996	train-rmse:2.54563
# [637]	eval-rmse:2.09958	train-rmse:2.54556
# [638]	eval-rmse:2.09953	train-rmse:2.54545
# [639]	eval-rmse:2.09949	train-rmse:2.5453
# [640]	eval-rmse:2.09949	train-rmse:2.54512
# [641]	eval-rmse:2.09945	train-rmse:2.54491
# [642]	eval-rmse:2.09944	train-rmse:2.54475
# [643]	eval-rmse:2.09941	train-rmse:2.54463
# [644]	eval-rmse:2.09941	train-rmse:2.54451
# [645]	eval-rmse:2.0994	train-rmse:2.54436
# [646]	eval-rmse:2.09938	train-rmse:2.54422
# [647]	eval-rmse:2.09937	train-rmse:2.54414
# [648]	eval-rmse:2.09936	train-rmse:2.54409
# [649]	eval-rmse:2.09935	train-rmse:2.54397
# [650]	eval-rmse:2.09929	train-rmse:2.54389
# [651]	eval-rmse:2.09927	train-rmse:2.54378
# [652]	eval-rmse:2.09925	train-rmse:2.54367
# [653]	eval-rmse:2.09923	train-rmse:2.54357
# [654]	eval-rmse:2.09925	train-rmse:2.54339
# [655]	eval-rmse:2.09923	train-rmse:2.54327
# [656]	eval-rmse:2.09922	train-rmse:2.5432
# [657]	eval-rmse:2.09921	train-rmse:2.54304
# [658]	eval-rmse:2.09917	train-rmse:2.54281
# [659]	eval-rmse:2.09915	train-rmse:2.54274
# [660]	eval-rmse:2.09915	train-rmse:2.54263
# [661]	eval-rmse:2.09909	train-rmse:2.54255
# [662]	eval-rmse:2.09908	train-rmse:2.5425
# [663]	eval-rmse:2.09907	train-rmse:2.54238
# [664]	eval-rmse:2.09905	train-rmse:2.5423
# [665]	eval-rmse:2.09904	train-rmse:2.54218
# [666]	eval-rmse:2.099	train-rmse:2.54207
# [667]	eval-rmse:2.09897	train-rmse:2.54193
# [668]	eval-rmse:2.09894	train-rmse:2.54185
# [669]	eval-rmse:2.09895	train-rmse:2.54178
# [670]	eval-rmse:2.09898	train-rmse:2.54171
# [671]	eval-rmse:2.09896	train-rmse:2.5416
# [672]	eval-rmse:2.09893	train-rmse:2.54147
# [673]	eval-rmse:2.09892	train-rmse:2.54138
# [674]	eval-rmse:2.09888	train-rmse:2.54131
# [675]	eval-rmse:2.09888	train-rmse:2.54124
# [676]	eval-rmse:2.09882	train-rmse:2.54115
# [677]	eval-rmse:2.09879	train-rmse:2.54104
# [678]	eval-rmse:2.0988	train-rmse:2.54097
# [679]	eval-rmse:2.09875	train-rmse:2.54087
# [680]	eval-rmse:2.09871	train-rmse:2.54079
# [681]	eval-rmse:2.09869	train-rmse:2.54069
# [682]	eval-rmse:2.09868	train-rmse:2.54058
# [683]	eval-rmse:2.09868	train-rmse:2.54052
# [684]	eval-rmse:2.09863	train-rmse:2.54039
# [685]	eval-rmse:2.09862	train-rmse:2.54029
# [686]	eval-rmse:2.09858	train-rmse:2.54022
# [687]	eval-rmse:2.09858	train-rmse:2.54005
# [688]	eval-rmse:2.09853	train-rmse:2.53995
# [689]	eval-rmse:2.09851	train-rmse:2.53988
# [690]	eval-rmse:2.09847	train-rmse:2.53978
# [691]	eval-rmse:2.09847	train-rmse:2.53967
# [692]	eval-rmse:2.09846	train-rmse:2.53945
# [693]	eval-rmse:2.09842	train-rmse:2.53929
# [694]	eval-rmse:2.0984	train-rmse:2.5392
# [695]	eval-rmse:2.09836	train-rmse:2.53905
# [696]	eval-rmse:2.09836	train-rmse:2.53898
# [697]	eval-rmse:2.09834	train-rmse:2.53891
# [698]	eval-rmse:2.09842	train-rmse:2.53885
# [699]	eval-rmse:2.0984	train-rmse:2.53875
# [700]	eval-rmse:2.0984	train-rmse:2.53859
# [701]	eval-rmse:2.09836	train-rmse:2.53849
# [702]	eval-rmse:2.09836	train-rmse:2.53844
# [703]	eval-rmse:2.09836	train-rmse:2.53833
# [704]	eval-rmse:2.09835	train-rmse:2.53825
# [705]	eval-rmse:2.09835	train-rmse:2.53817
# [706]	eval-rmse:2.09834	train-rmse:2.53808
# [707]	eval-rmse:2.09834	train-rmse:2.53789
# [708]	eval-rmse:2.09831	train-rmse:2.53777
# [709]	eval-rmse:2.09828	train-rmse:2.53765
# [710]	eval-rmse:2.09826	train-rmse:2.53758
# [711]	eval-rmse:2.09825	train-rmse:2.53749
# [712]	eval-rmse:2.09822	train-rmse:2.53741
# [713]	eval-rmse:2.09823	train-rmse:2.53733
# [714]	eval-rmse:2.09821	train-rmse:2.5371
# [715]	eval-rmse:2.0982	train-rmse:2.53702
# [716]	eval-rmse:2.09819	train-rmse:2.53695
# [717]	eval-rmse:2.09817	train-rmse:2.53685
# [718]	eval-rmse:2.09816	train-rmse:2.53673
# [719]	eval-rmse:2.09815	train-rmse:2.53667
# [720]	eval-rmse:2.09812	train-rmse:2.53659
# [721]	eval-rmse:2.09805	train-rmse:2.53647
# [722]	eval-rmse:2.09806	train-rmse:2.53639
# [723]	eval-rmse:2.09802	train-rmse:2.53631
# [724]	eval-rmse:2.09798	train-rmse:2.53625
# [725]	eval-rmse:2.09796	train-rmse:2.53613
# [726]	eval-rmse:2.09795	train-rmse:2.53602
# [727]	eval-rmse:2.09796	train-rmse:2.53589
# [728]	eval-rmse:2.09792	train-rmse:2.53584
# [729]	eval-rmse:2.09788	train-rmse:2.53575
# [730]	eval-rmse:2.09787	train-rmse:2.53563
# [731]	eval-rmse:2.09786	train-rmse:2.53557
# [732]	eval-rmse:2.09787	train-rmse:2.53548
# [733]	eval-rmse:2.09781	train-rmse:2.53536
# [734]	eval-rmse:2.0978	train-rmse:2.53532
# [735]	eval-rmse:2.09775	train-rmse:2.53524
# [736]	eval-rmse:2.09774	train-rmse:2.5351
# [737]	eval-rmse:2.09775	train-rmse:2.53499
# [738]	eval-rmse:2.0977	train-rmse:2.53478
# [739]	eval-rmse:2.0977	train-rmse:2.53472
# [740]	eval-rmse:2.09766	train-rmse:2.53465
# [741]	eval-rmse:2.09766	train-rmse:2.5346
# [742]	eval-rmse:2.09768	train-rmse:2.53436
# [743]	eval-rmse:2.09767	train-rmse:2.5343
# [744]	eval-rmse:2.09776	train-rmse:2.53423
# [745]	eval-rmse:2.09775	train-rmse:2.53409
# [746]	eval-rmse:2.09776	train-rmse:2.53401
# [747]	eval-rmse:2.09777	train-rmse:2.53396
# [748]	eval-rmse:2.09779	train-rmse:2.53383
# [749]	eval-rmse:2.09778	train-rmse:2.53361
# [750]	eval-rmse:2.0978	train-rmse:2.53353
# [751]	eval-rmse:2.09779	train-rmse:2.53337
# [752]	eval-rmse:2.09777	train-rmse:2.53333
# [753]	eval-rmse:2.09775	train-rmse:2.53323
# [754]	eval-rmse:2.09775	train-rmse:2.53315
# [755]	eval-rmse:2.0978	train-rmse:2.53301
# [756]	eval-rmse:2.0978	train-rmse:2.53289
# [757]	eval-rmse:2.09779	train-rmse:2.53283
# [758]	eval-rmse:2.09778	train-rmse:2.53271
# [759]	eval-rmse:2.09785	train-rmse:2.5326
# [760]	eval-rmse:2.09785	train-rmse:2.53251
# [761]	eval-rmse:2.09784	train-rmse:2.5324
# [762]	eval-rmse:2.0978	train-rmse:2.53236
# [763]	eval-rmse:2.09785	train-rmse:2.5323
# [764]	eval-rmse:2.09787	train-rmse:2.53225
# [765]	eval-rmse:2.09783	train-rmse:2.53207
# [766]	eval-rmse:2.09779	train-rmse:2.532
# [767]	eval-rmse:2.09781	train-rmse:2.53189
# [768]	eval-rmse:2.09779	train-rmse:2.53177
# [769]	eval-rmse:2.09778	train-rmse:2.53157
# [770]	eval-rmse:2.09774	train-rmse:2.53149
# [771]	eval-rmse:2.09776	train-rmse:2.53135
# [772]	eval-rmse:2.09772	train-rmse:2.53118
# [773]	eval-rmse:2.0977	train-rmse:2.53111
# [774]	eval-rmse:2.09765	train-rmse:2.53099
# [775]	eval-rmse:2.09763	train-rmse:2.53088
# [776]	eval-rmse:2.09764	train-rmse:2.53081
# [777]	eval-rmse:2.0976	train-rmse:2.5307
# [778]	eval-rmse:2.09754	train-rmse:2.53063
# [779]	eval-rmse:2.09752	train-rmse:2.53059
# [780]	eval-rmse:2.09753	train-rmse:2.53052
# [781]	eval-rmse:2.09751	train-rmse:2.53047
# [782]	eval-rmse:2.09752	train-rmse:2.53038
# [783]	eval-rmse:2.09749	train-rmse:2.53032
# [784]	eval-rmse:2.09745	train-rmse:2.53027
# [785]	eval-rmse:2.09744	train-rmse:2.53014
# [786]	eval-rmse:2.09742	train-rmse:2.53005
# [787]	eval-rmse:2.0974	train-rmse:2.52992
# [788]	eval-rmse:2.09742	train-rmse:2.52987
# [789]	eval-rmse:2.09737	train-rmse:2.52978
# [790]	eval-rmse:2.09739	train-rmse:2.52971
# [791]	eval-rmse:2.09739	train-rmse:2.52965
# [792]	eval-rmse:2.09733	train-rmse:2.52956
# [793]	eval-rmse:2.09715	train-rmse:2.52949
# [794]	eval-rmse:2.09714	train-rmse:2.52943
# [795]	eval-rmse:2.09713	train-rmse:2.52928
# [796]	eval-rmse:2.0971	train-rmse:2.52918
# [797]	eval-rmse:2.0971	train-rmse:2.5291
# [798]	eval-rmse:2.09705	train-rmse:2.52898
# [799]	eval-rmse:2.09706	train-rmse:2.52892
# [800]	eval-rmse:2.09706	train-rmse:2.52885
# [801]	eval-rmse:2.09707	train-rmse:2.52874
# [802]	eval-rmse:2.09707	train-rmse:2.52863
# [803]	eval-rmse:2.09706	train-rmse:2.5285
# [804]	eval-rmse:2.09705	train-rmse:2.52841
# [805]	eval-rmse:2.09704	train-rmse:2.52834
# [806]	eval-rmse:2.09704	train-rmse:2.52827
# [807]	eval-rmse:2.09703	train-rmse:2.52813
# [808]	eval-rmse:2.09701	train-rmse:2.52799
# [809]	eval-rmse:2.097	train-rmse:2.52791
# [810]	eval-rmse:2.09701	train-rmse:2.52781
# [811]	eval-rmse:2.097	train-rmse:2.52777
# [812]	eval-rmse:2.09701	train-rmse:2.52772
# [813]	eval-rmse:2.09701	train-rmse:2.52764
# [814]	eval-rmse:2.09699	train-rmse:2.52748
# [815]	eval-rmse:2.097	train-rmse:2.52732
# [816]	eval-rmse:2.09701	train-rmse:2.52721
# [817]	eval-rmse:2.09698	train-rmse:2.52715
# [818]	eval-rmse:2.09698	train-rmse:2.52703
# [819]	eval-rmse:2.09699	train-rmse:2.52693
# [820]	eval-rmse:2.09697	train-rmse:2.52688
# [821]	eval-rmse:2.09697	train-rmse:2.52683
# [822]	eval-rmse:2.09695	train-rmse:2.52678
# [823]	eval-rmse:2.09696	train-rmse:2.52669
# [824]	eval-rmse:2.09698	train-rmse:2.52656
# [825]	eval-rmse:2.09694	train-rmse:2.5264
# [826]	eval-rmse:2.09696	train-rmse:2.5263
# [827]	eval-rmse:2.09696	train-rmse:2.52607
# [828]	eval-rmse:2.09693	train-rmse:2.52601
# [829]	eval-rmse:2.09689	train-rmse:2.52593
# [830]	eval-rmse:2.09687	train-rmse:2.52588
# [831]	eval-rmse:2.09684	train-rmse:2.52583
# [832]	eval-rmse:2.09686	train-rmse:2.52571
# [833]	eval-rmse:2.09685	train-rmse:2.52564
# [834]	eval-rmse:2.09685	train-rmse:2.52558
# [835]	eval-rmse:2.09684	train-rmse:2.52553
# [836]	eval-rmse:2.09685	train-rmse:2.52543
# [837]	eval-rmse:2.09682	train-rmse:2.52534
# [838]	eval-rmse:2.09681	train-rmse:2.52525
# [839]	eval-rmse:2.09678	train-rmse:2.52517
# [840]	eval-rmse:2.09675	train-rmse:2.5251
# [841]	eval-rmse:2.09673	train-rmse:2.52501
# [842]	eval-rmse:2.09667	train-rmse:2.52495
# [843]	eval-rmse:2.09663	train-rmse:2.52488
# [844]	eval-rmse:2.0966	train-rmse:2.5248
# [845]	eval-rmse:2.09658	train-rmse:2.52473
# [846]	eval-rmse:2.09658	train-rmse:2.52464
# [847]	eval-rmse:2.09657	train-rmse:2.52459
# [848]	eval-rmse:2.09657	train-rmse:2.52455
# [849]	eval-rmse:2.09652	train-rmse:2.5245
# [850]	eval-rmse:2.09651	train-rmse:2.5244
# [851]	eval-rmse:2.09653	train-rmse:2.52429
# [852]	eval-rmse:2.09651	train-rmse:2.52422
# [853]	eval-rmse:2.09652	train-rmse:2.5241
# [854]	eval-rmse:2.09653	train-rmse:2.52404
# [855]	eval-rmse:2.09651	train-rmse:2.52384
# [856]	eval-rmse:2.09649	train-rmse:2.52374
# [857]	eval-rmse:2.09646	train-rmse:2.52368
# [858]	eval-rmse:2.09648	train-rmse:2.52361
# [859]	eval-rmse:2.09643	train-rmse:2.52353
# [860]	eval-rmse:2.09641	train-rmse:2.52347
# [861]	eval-rmse:2.09643	train-rmse:2.52338
# [862]	eval-rmse:2.09642	train-rmse:2.52328
# [863]	eval-rmse:2.0964	train-rmse:2.52318
# [864]	eval-rmse:2.09638	train-rmse:2.52314
# [865]	eval-rmse:2.09639	train-rmse:2.52307
# [866]	eval-rmse:2.09634	train-rmse:2.52301
# [867]	eval-rmse:2.09633	train-rmse:2.52295
# [868]	eval-rmse:2.09637	train-rmse:2.52287
# [869]	eval-rmse:2.09639	train-rmse:2.52281
# [870]	eval-rmse:2.09639	train-rmse:2.52269
# [871]	eval-rmse:2.0964	train-rmse:2.52253
# [872]	eval-rmse:2.09641	train-rmse:2.52249
# [873]	eval-rmse:2.09638	train-rmse:2.5224
# [874]	eval-rmse:2.09638	train-rmse:2.52233
# [875]	eval-rmse:2.09636	train-rmse:2.52227
# [876]	eval-rmse:2.09642	train-rmse:2.52219
# [877]	eval-rmse:2.0964	train-rmse:2.52213
# [878]	eval-rmse:2.09637	train-rmse:2.52208
# [879]	eval-rmse:2.09638	train-rmse:2.522
# [880]	eval-rmse:2.09637	train-rmse:2.52192
# [881]	eval-rmse:2.0964	train-rmse:2.52185
# [882]	eval-rmse:2.0964	train-rmse:2.52176
# [883]	eval-rmse:2.09641	train-rmse:2.52168
# [884]	eval-rmse:2.09638	train-rmse:2.52158
# [885]	eval-rmse:2.09638	train-rmse:2.52154
# [886]	eval-rmse:2.09639	train-rmse:2.52148
# [887]	eval-rmse:2.09636	train-rmse:2.52143
# [888]	eval-rmse:2.09634	train-rmse:2.52135
# [889]	eval-rmse:2.09632	train-rmse:2.52128
# [890]	eval-rmse:2.09632	train-rmse:2.52117
# [891]	eval-rmse:2.09631	train-rmse:2.52107
# [892]	eval-rmse:2.09628	train-rmse:2.52096
# [893]	eval-rmse:2.09633	train-rmse:2.52078
# [894]	eval-rmse:2.09633	train-rmse:2.52065
# [895]	eval-rmse:2.09632	train-rmse:2.52059
# [896]	eval-rmse:2.09633	train-rmse:2.52053
# [897]	eval-rmse:2.09633	train-rmse:2.52048
# [898]	eval-rmse:2.09631	train-rmse:2.52043
# [899]	eval-rmse:2.09628	train-rmse:2.52036
# [900]	eval-rmse:2.09626	train-rmse:2.52027
# [901]	eval-rmse:2.09625	train-rmse:2.52022
# [902]	eval-rmse:2.09624	train-rmse:2.52013
# [903]	eval-rmse:2.09625	train-rmse:2.51997
# [904]	eval-rmse:2.09625	train-rmse:2.51993
# [905]	eval-rmse:2.09631	train-rmse:2.51985
# [906]	eval-rmse:2.09628	train-rmse:2.51977
# [907]	eval-rmse:2.09628	train-rmse:2.51969
# [908]	eval-rmse:2.09628	train-rmse:2.5196
# [909]	eval-rmse:2.09626	train-rmse:2.51952
# [910]	eval-rmse:2.09623	train-rmse:2.51947
# [911]	eval-rmse:2.09621	train-rmse:2.51933
# [912]	eval-rmse:2.09617	train-rmse:2.51924
# [913]	eval-rmse:2.09619	train-rmse:2.51913
# [914]	eval-rmse:2.09622	train-rmse:2.5191
# [915]	eval-rmse:2.09624	train-rmse:2.51907
# [916]	eval-rmse:2.09621	train-rmse:2.519
# [917]	eval-rmse:2.09625	train-rmse:2.51892
# [918]	eval-rmse:2.09624	train-rmse:2.51886
# [919]	eval-rmse:2.09624	train-rmse:2.51876
# [920]	eval-rmse:2.09621	train-rmse:2.51872
# [921]	eval-rmse:2.09622	train-rmse:2.51863
# [922]	eval-rmse:2.09622	train-rmse:2.51857
# [923]	eval-rmse:2.09621	train-rmse:2.51848
# [924]	eval-rmse:2.09619	train-rmse:2.51838
# [925]	eval-rmse:2.09617	train-rmse:2.51834
# [926]	eval-rmse:2.09616	train-rmse:2.5183
# [927]	eval-rmse:2.09613	train-rmse:2.51823
# [928]	eval-rmse:2.09618	train-rmse:2.51806
# [929]	eval-rmse:2.09616	train-rmse:2.518
# [930]	eval-rmse:2.09616	train-rmse:2.51792
# [931]	eval-rmse:2.09616	train-rmse:2.51787
# [932]	eval-rmse:2.09615	train-rmse:2.51781
# [933]	eval-rmse:2.09616	train-rmse:2.51774
# [934]	eval-rmse:2.09614	train-rmse:2.51769
# [935]	eval-rmse:2.09613	train-rmse:2.51751
# [936]	eval-rmse:2.09615	train-rmse:2.51743
# [937]	eval-rmse:2.09612	train-rmse:2.51737
# [938]	eval-rmse:2.09613	train-rmse:2.51732
# [939]	eval-rmse:2.09612	train-rmse:2.5172
# [940]	eval-rmse:2.09611	train-rmse:2.51712
# [941]	eval-rmse:2.09613	train-rmse:2.51708
# [942]	eval-rmse:2.09612	train-rmse:2.51702
# [943]	eval-rmse:2.09612	train-rmse:2.51695
# [944]	eval-rmse:2.09608	train-rmse:2.51685
# [945]	eval-rmse:2.09607	train-rmse:2.5168
# [946]	eval-rmse:2.09604	train-rmse:2.51672
# [947]	eval-rmse:2.09602	train-rmse:2.51668
# [948]	eval-rmse:2.09603	train-rmse:2.51666
# [949]	eval-rmse:2.09603	train-rmse:2.51647
# [950]	eval-rmse:2.09599	train-rmse:2.51642
# [951]	eval-rmse:2.09598	train-rmse:2.51636
# [952]	eval-rmse:2.096	train-rmse:2.51627
# [953]	eval-rmse:2.09597	train-rmse:2.51618
# [954]	eval-rmse:2.09599	train-rmse:2.51604
# [955]	eval-rmse:2.09598	train-rmse:2.51599
# [956]	eval-rmse:2.09597	train-rmse:2.5159
# [957]	eval-rmse:2.09596	train-rmse:2.51579
# [958]	eval-rmse:2.09595	train-rmse:2.51567
# [959]	eval-rmse:2.09593	train-rmse:2.51563
# [960]	eval-rmse:2.09593	train-rmse:2.51555
# [961]	eval-rmse:2.09592	train-rmse:2.51551
# [962]	eval-rmse:2.09589	train-rmse:2.51547
# [963]	eval-rmse:2.09587	train-rmse:2.51541
# [964]	eval-rmse:2.09586	train-rmse:2.51532
# [965]	eval-rmse:2.09585	train-rmse:2.51525
# [966]	eval-rmse:2.09585	train-rmse:2.51518
# [967]	eval-rmse:2.09585	train-rmse:2.51511
# [968]	eval-rmse:2.09592	train-rmse:2.51504
# [969]	eval-rmse:2.0959	train-rmse:2.51498
# [970]	eval-rmse:2.0959	train-rmse:2.51482
# [971]	eval-rmse:2.09587	train-rmse:2.51472
# [972]	eval-rmse:2.09587	train-rmse:2.5147
# [973]	eval-rmse:2.09585	train-rmse:2.51463
# [974]	eval-rmse:2.09581	train-rmse:2.51454
# [975]	eval-rmse:2.0958	train-rmse:2.51443
# [976]	eval-rmse:2.09581	train-rmse:2.51436
# [977]	eval-rmse:2.09581	train-rmse:2.51432
# [978]	eval-rmse:2.09577	train-rmse:2.51414
# [979]	eval-rmse:2.09576	train-rmse:2.51408
# [980]	eval-rmse:2.09578	train-rmse:2.51395
# [981]	eval-rmse:2.09579	train-rmse:2.51391
# [982]	eval-rmse:2.0958	train-rmse:2.51384
# [983]	eval-rmse:2.09581	train-rmse:2.51377
# [984]	eval-rmse:2.09578	train-rmse:2.51371
# [985]	eval-rmse:2.09581	train-rmse:2.51355
# [986]	eval-rmse:2.09581	train-rmse:2.51349
# [987]	eval-rmse:2.09585	train-rmse:2.51341
# [988]	eval-rmse:2.09589	train-rmse:2.51336
# [989]	eval-rmse:2.09588	train-rmse:2.51331
# [990]	eval-rmse:2.09589	train-rmse:2.51319
# [991]	eval-rmse:2.09592	train-rmse:2.51311
# [992]	eval-rmse:2.09593	train-rmse:2.51302
# [993]	eval-rmse:2.0959	train-rmse:2.51297
# [994]	eval-rmse:2.09586	train-rmse:2.51293
# [995]	eval-rmse:2.09587	train-rmse:2.51283
# [996]	eval-rmse:2.09587	train-rmse:2.51271
# [997]	eval-rmse:2.09586	train-rmse:2.51265
# [998]	eval-rmse:2.09583	train-rmse:2.51257
# [999]	eval-rmse:2.09583	train-rmse:2.51251
# [1000]	eval-rmse:2.09582	train-rmse:2.5124
# [1001]	eval-rmse:2.09585	train-rmse:2.51232
# [1002]	eval-rmse:2.09586	train-rmse:2.51223
# [1003]	eval-rmse:2.09585	train-rmse:2.51215
# [1004]	eval-rmse:2.09589	train-rmse:2.51208
# [1005]	eval-rmse:2.09591	train-rmse:2.51199
# [1006]	eval-rmse:2.09586	train-rmse:2.51194
# [1007]	eval-rmse:2.09586	train-rmse:2.51185
# [1008]	eval-rmse:2.09589	train-rmse:2.51168
# [1009]	eval-rmse:2.09585	train-rmse:2.51159
# [1010]	eval-rmse:2.09585	train-rmse:2.51152
# [1011]	eval-rmse:2.09587	train-rmse:2.51147
# [1012]	eval-rmse:2.09588	train-rmse:2.5114
# [1013]	eval-rmse:2.09587	train-rmse:2.51133
# [1014]	eval-rmse:2.09583	train-rmse:2.51122
# [1015]	eval-rmse:2.0958	train-rmse:2.51112
# [1016]	eval-rmse:2.09578	train-rmse:2.51106
# [1017]	eval-rmse:2.09577	train-rmse:2.51102
# [1018]	eval-rmse:2.09575	train-rmse:2.51095
# [1019]	eval-rmse:2.09573	train-rmse:2.51086
# [1020]	eval-rmse:2.09571	train-rmse:2.51081
# [1021]	eval-rmse:2.09571	train-rmse:2.51076
# [1022]	eval-rmse:2.09571	train-rmse:2.5107
# [1023]	eval-rmse:2.09572	train-rmse:2.51065
# [1024]	eval-rmse:2.09569	train-rmse:2.51052
# [1025]	eval-rmse:2.09577	train-rmse:2.51048
# [1026]	eval-rmse:2.09577	train-rmse:2.51041
# [1027]	eval-rmse:2.09575	train-rmse:2.51036
# [1028]	eval-rmse:2.09573	train-rmse:2.5103
# [1029]	eval-rmse:2.09572	train-rmse:2.5102
# [1030]	eval-rmse:2.09573	train-rmse:2.51007
# [1031]	eval-rmse:2.09573	train-rmse:2.51002
# [1032]	eval-rmse:2.09571	train-rmse:2.50997
# [1033]	eval-rmse:2.09569	train-rmse:2.50989
# [1034]	eval-rmse:2.09569	train-rmse:2.5098
# [1035]	eval-rmse:2.09569	train-rmse:2.50973
# [1036]	eval-rmse:2.09568	train-rmse:2.50967
# [1037]	eval-rmse:2.09565	train-rmse:2.50961
# [1038]	eval-rmse:2.09566	train-rmse:2.50956
# [1039]	eval-rmse:2.09568	train-rmse:2.50949
# [1040]	eval-rmse:2.09564	train-rmse:2.50943
# [1041]	eval-rmse:2.09565	train-rmse:2.50938
# [1042]	eval-rmse:2.09562	train-rmse:2.50931
# [1043]	eval-rmse:2.0956	train-rmse:2.50925
# [1044]	eval-rmse:2.09561	train-rmse:2.50913
# [1045]	eval-rmse:2.09565	train-rmse:2.50907
# [1046]	eval-rmse:2.09565	train-rmse:2.50901
# [1047]	eval-rmse:2.09565	train-rmse:2.50891
# [1048]	eval-rmse:2.09561	train-rmse:2.50885
# [1049]	eval-rmse:2.0956	train-rmse:2.50881
# [1050]	eval-rmse:2.09561	train-rmse:2.50873
# [1051]	eval-rmse:2.09563	train-rmse:2.5087
# [1052]	eval-rmse:2.09562	train-rmse:2.50861
# [1053]	eval-rmse:2.09561	train-rmse:2.50854
# [1054]	eval-rmse:2.09563	train-rmse:2.50846
# [1055]	eval-rmse:2.09559	train-rmse:2.50842
# [1056]	eval-rmse:2.09561	train-rmse:2.50831
# [1057]	eval-rmse:2.09559	train-rmse:2.50828
# [1058]	eval-rmse:2.0956	train-rmse:2.5082
# [1059]	eval-rmse:2.09559	train-rmse:2.50808
# [1060]	eval-rmse:2.09557	train-rmse:2.50796
# [1061]	eval-rmse:2.09557	train-rmse:2.50789
# [1062]	eval-rmse:2.09554	train-rmse:2.5078
# [1063]	eval-rmse:2.09556	train-rmse:2.50774
# [1064]	eval-rmse:2.09557	train-rmse:2.50764
# [1065]	eval-rmse:2.09551	train-rmse:2.50757
# [1066]	eval-rmse:2.09552	train-rmse:2.50752
# [1067]	eval-rmse:2.0955	train-rmse:2.50749
# [1068]	eval-rmse:2.0955	train-rmse:2.50745
# [1069]	eval-rmse:2.09549	train-rmse:2.50737
# [1070]	eval-rmse:2.09548	train-rmse:2.50727
# [1071]	eval-rmse:2.09549	train-rmse:2.50718
# [1072]	eval-rmse:2.0955	train-rmse:2.50711
# [1073]	eval-rmse:2.09549	train-rmse:2.507
# [1074]	eval-rmse:2.09549	train-rmse:2.50694
# [1075]	eval-rmse:2.09552	train-rmse:2.50686
# [1076]	eval-rmse:2.09554	train-rmse:2.50673
# [1077]	eval-rmse:2.09555	train-rmse:2.50669
# [1078]	eval-rmse:2.09554	train-rmse:2.50659
# [1079]	eval-rmse:2.09553	train-rmse:2.50645
# [1080]	eval-rmse:2.09551	train-rmse:2.50637
# [1081]	eval-rmse:2.0955	train-rmse:2.50629
# [1082]	eval-rmse:2.09551	train-rmse:2.50621
# [1083]	eval-rmse:2.09549	train-rmse:2.50614
# [1084]	eval-rmse:2.09549	train-rmse:2.5061
# [1085]	eval-rmse:2.09547	train-rmse:2.50597
# [1086]	eval-rmse:2.09551	train-rmse:2.50588
# [1087]	eval-rmse:2.09554	train-rmse:2.5058
# [1088]	eval-rmse:2.09555	train-rmse:2.50574
# [1089]	eval-rmse:2.09553	train-rmse:2.50566
# [1090]	eval-rmse:2.09552	train-rmse:2.50559
# [1091]	eval-rmse:2.09551	train-rmse:2.50552
# [1092]	eval-rmse:2.0955	train-rmse:2.50546
# [1093]	eval-rmse:2.09551	train-rmse:2.5054
# [1094]	eval-rmse:2.09552	train-rmse:2.50532
# [1095]	eval-rmse:2.09548	train-rmse:2.50525
# [1096]	eval-rmse:2.09546	train-rmse:2.5052
# [1097]	eval-rmse:2.09546	train-rmse:2.50515
# [1098]	eval-rmse:2.09548	train-rmse:2.50508
# [1099]	eval-rmse:2.09548	train-rmse:2.50504
# [1100]	eval-rmse:2.09547	train-rmse:2.50497
# [1101]	eval-rmse:2.09546	train-rmse:2.5049
# [1102]	eval-rmse:2.0954	train-rmse:2.50486
# [1103]	eval-rmse:2.0954	train-rmse:2.50481
# [1104]	eval-rmse:2.09539	train-rmse:2.50478
# [1105]	eval-rmse:2.09539	train-rmse:2.5047
# [1106]	eval-rmse:2.09539	train-rmse:2.5046
# [1107]	eval-rmse:2.09539	train-rmse:2.50456
# [1108]	eval-rmse:2.09537	train-rmse:2.50453
# [1109]	eval-rmse:2.09536	train-rmse:2.50446
# [1110]	eval-rmse:2.09538	train-rmse:2.50436
# [1111]	eval-rmse:2.09538	train-rmse:2.5043
# [1112]	eval-rmse:2.09536	train-rmse:2.50422
# [1113]	eval-rmse:2.09535	train-rmse:2.50416
# [1114]	eval-rmse:2.09535	train-rmse:2.50412
# [1115]	eval-rmse:2.09535	train-rmse:2.50407
# [1116]	eval-rmse:2.09534	train-rmse:2.50395
# [1117]	eval-rmse:2.09535	train-rmse:2.50382
# ...
# [1635]	eval-rmse:2.09447	train-rmse:2.47416
# [1636]	eval-rmse:2.09447	train-rmse:2.47412
# [1637]	eval-rmse:2.09446	train-rmse:2.47406
# [1638]	eval-rmse:2.09446	train-rmse:2.47402
# [1639]	eval-rmse:2.09446	train-rmse:2.47397
# [1640]	eval-rmse:2.09441	train-rmse:2.47388
# [1641]	eval-rmse:2.09444	train-rmse:2.47383
# [1642]	eval-rmse:2.09443	train-rmse:2.47376
# [1643]	eval-rmse:2.09443	train-rmse:2.47373
# [1644]	eval-rmse:2.09443	train-rmse:2.47366
# [1645]	eval-rmse:2.09446	train-rmse:2.47363
# [1646]	eval-rmse:2.09446	train-rmse:2.47358
# [1647]	eval-rmse:2.09447	train-rmse:2.4735
# [1648]	eval-rmse:2.09446	train-rmse:2.47344
# [1649]	eval-rmse:2.09448	train-rmse:2.4734
# [1650]	eval-rmse:2.09448	train-rmse:2.47332
# [1651]	eval-rmse:2.09449	train-rmse:2.47326
# [1652]	eval-rmse:2.09449	train-rmse:2.47316
# [1653]	eval-rmse:2.0945	train-rmse:2.47313
# [1654]	eval-rmse:2.0945	train-rmse:2.47311
# [1655]	eval-rmse:2.0945	train-rmse:2.47309
# [1656]	eval-rmse:2.0945	train-rmse:2.47306
# [1657]	eval-rmse:2.09448	train-rmse:2.47302
# [1658]	eval-rmse:2.09446	train-rmse:2.47297
# [1659]	eval-rmse:2.09446	train-rmse:2.47293
# [1660]	eval-rmse:2.09448	train-rmse:2.47286
# [1661]	eval-rmse:2.09447	train-rmse:2.47281
# [1662]	eval-rmse:2.09451	train-rmse:2.47273
# [1663]	eval-rmse:2.09449	train-rmse:2.47268
# [1664]	eval-rmse:2.0945	train-rmse:2.47263
# [1665]	eval-rmse:2.0945	train-rmse:2.47252
# [1666]	eval-rmse:2.09449	train-rmse:2.47248
# [1667]	eval-rmse:2.09449	train-rmse:2.47243
# [1668]	eval-rmse:2.09448	train-rmse:2.47237
# [1669]	eval-rmse:2.09447	train-rmse:2.47234
# [1670]	eval-rmse:2.09448	train-rmse:2.47227
# [1671]	eval-rmse:2.09447	train-rmse:2.47224
# [1672]	eval-rmse:2.09448	train-rmse:2.4722
# [1673]	eval-rmse:2.0945	train-rmse:2.47215
# [1674]	eval-rmse:2.09449	train-rmse:2.47211
# [1675]	eval-rmse:2.09449	train-rmse:2.47208
# [1676]	eval-rmse:2.09448	train-rmse:2.47203
# [1677]	eval-rmse:2.09449	train-rmse:2.47198
# [1678]	eval-rmse:2.0945	train-rmse:2.47195
# [1679]	eval-rmse:2.0945	train-rmse:2.47191
# [1680]	eval-rmse:2.0945	train-rmse:2.4719
# [1681]	eval-rmse:2.09449	train-rmse:2.47181
# [1682]	eval-rmse:2.09447	train-rmse:2.47175
# [1683]	eval-rmse:2.09448	train-rmse:2.4717
# [1684]	eval-rmse:2.09447	train-rmse:2.47164
# [1685]	eval-rmse:2.09448	train-rmse:2.47157
# [1686]	eval-rmse:2.09453	train-rmse:2.47153
# [1687]	eval-rmse:2.09452	train-rmse:2.47149
# [1688]	eval-rmse:2.09452	train-rmse:2.47143
# [1689]	eval-rmse:2.09449	train-rmse:2.47139
# [1690]	eval-rmse:2.09452	train-rmse:2.47135
# [1691]	eval-rmse:2.0945	train-rmse:2.47128
# [1692]	eval-rmse:2.09451	train-rmse:2.47122
# [1693]	eval-rmse:2.09451	train-rmse:2.47119
# [1694]	eval-rmse:2.09458	train-rmse:2.4711
# [1695]	eval-rmse:2.09457	train-rmse:2.47104
# [1696]	eval-rmse:2.09459	train-rmse:2.47101
# [1697]	eval-rmse:2.09458	train-rmse:2.47098
# [1698]	eval-rmse:2.09456	train-rmse:2.47096
# [1699]	eval-rmse:2.09454	train-rmse:2.47091
# [1700]	eval-rmse:2.09454	train-rmse:2.47085
# [1701]	eval-rmse:2.09454	train-rmse:2.47079
# [1702]	eval-rmse:2.09454	train-rmse:2.47075
# [1703]	eval-rmse:2.09455	train-rmse:2.4707
# [1704]	eval-rmse:2.09457	train-rmse:2.47064
# [1705]	eval-rmse:2.0946	train-rmse:2.47051
# [1706]	eval-rmse:2.09458	train-rmse:2.47046
# [1707]	eval-rmse:2.09453	train-rmse:2.47041
# [1708]	eval-rmse:2.09453	train-rmse:2.47039
# [1709]	eval-rmse:2.09453	train-rmse:2.47035
# [1710]	eval-rmse:2.09453	train-rmse:2.47033
# [1711]	eval-rmse:2.09449	train-rmse:2.47029
# [1712]	eval-rmse:2.09445	train-rmse:2.47021
# [1713]	eval-rmse:2.09445	train-rmse:2.47018
# [1714]	eval-rmse:2.0944	train-rmse:2.47014
# [1715]	eval-rmse:2.0944	train-rmse:2.47011
# [1716]	eval-rmse:2.09442	train-rmse:2.47009
# [1717]	eval-rmse:2.09442	train-rmse:2.47004
# [1718]	eval-rmse:2.09441	train-rmse:2.47
# [1719]	eval-rmse:2.0944	train-rmse:2.46995
# [1720]	eval-rmse:2.09439	train-rmse:2.46993
# [1721]	eval-rmse:2.09437	train-rmse:2.4699
# [1722]	eval-rmse:2.09437	train-rmse:2.46987
# [1723]	eval-rmse:2.09442	train-rmse:2.46982
# [1724]	eval-rmse:2.09444	train-rmse:2.46976
# [1725]	eval-rmse:2.09444	train-rmse:2.46973
# [1726]	eval-rmse:2.09447	train-rmse:2.4697
# [1727]	eval-rmse:2.09447	train-rmse:2.46965
# [1728]	eval-rmse:2.09447	train-rmse:2.46963
# [1729]	eval-rmse:2.09445	train-rmse:2.4696
# [1730]	eval-rmse:2.09447	train-rmse:2.46956
# [1731]	eval-rmse:2.09448	train-rmse:2.46952
# [1732]	eval-rmse:2.0945	train-rmse:2.46949
# [1733]	eval-rmse:2.09451	train-rmse:2.46945
# [1734]	eval-rmse:2.09449	train-rmse:2.4694
# [1735]	eval-rmse:2.0945	train-rmse:2.46931
# [1736]	eval-rmse:2.09446	train-rmse:2.46926
# [1737]	eval-rmse:2.09445	train-rmse:2.46922
# [1738]	eval-rmse:2.09444	train-rmse:2.4692
# [1739]	eval-rmse:2.09443	train-rmse:2.46914
# [1740]	eval-rmse:2.09439	train-rmse:2.46908
# [1741]	eval-rmse:2.0944	train-rmse:2.46904
# [1742]	eval-rmse:2.09441	train-rmse:2.46902
# [1743]	eval-rmse:2.0944	train-rmse:2.46897
# [1744]	eval-rmse:2.09442	train-rmse:2.46894
# [1745]	eval-rmse:2.09444	train-rmse:2.46887
# [1746]	eval-rmse:2.09445	train-rmse:2.46883
# [1747]	eval-rmse:2.09445	train-rmse:2.46875
# [1748]	eval-rmse:2.09446	train-rmse:2.46871
# [1749]	eval-rmse:2.09446	train-rmse:2.46866
# [1750]	eval-rmse:2.09449	train-rmse:2.4686
# [1751]	eval-rmse:2.09449	train-rmse:2.46858
# [1752]	eval-rmse:2.0945	train-rmse:2.46854
# [1753]	eval-rmse:2.0945	train-rmse:2.46849
# [1754]	eval-rmse:2.09449	train-rmse:2.46846
# [1755]	eval-rmse:2.09448	train-rmse:2.46842
# [1756]	eval-rmse:2.09448	train-rmse:2.4684
# [1757]	eval-rmse:2.09448	train-rmse:2.46835
# [1758]	eval-rmse:2.09446	train-rmse:2.4683
# [1759]	eval-rmse:2.09448	train-rmse:2.46824
# [1760]	eval-rmse:2.09448	train-rmse:2.46821
# [1761]	eval-rmse:2.09448	train-rmse:2.4682
# [1762]	eval-rmse:2.09446	train-rmse:2.46815
# [1763]	eval-rmse:2.09445	train-rmse:2.46812
# [1764]	eval-rmse:2.09443	train-rmse:2.46804
# [1765]	eval-rmse:2.09442	train-rmse:2.46803
# [1766]	eval-rmse:2.09441	train-rmse:2.46799
# [1767]	eval-rmse:2.09441	train-rmse:2.46792
# [1768]	eval-rmse:2.09441	train-rmse:2.46787
# [1769]	eval-rmse:2.0944	train-rmse:2.46784
# [1770]	eval-rmse:2.09438	train-rmse:2.46779
# [1771]	eval-rmse:2.09439	train-rmse:2.46776
# [1772]	eval-rmse:2.09438	train-rmse:2.46769
# [1773]	eval-rmse:2.09442	train-rmse:2.46766
# [1774]	eval-rmse:2.09443	train-rmse:2.46761
# [1775]	eval-rmse:2.09443	train-rmse:2.46756
# [1776]	eval-rmse:2.09435	train-rmse:2.46753
# [1777]	eval-rmse:2.09435	train-rmse:2.46745
# [1778]	eval-rmse:2.09435	train-rmse:2.46742
# [1779]	eval-rmse:2.09436	train-rmse:2.46738
# [1780]	eval-rmse:2.09434	train-rmse:2.46734
# [1781]	eval-rmse:2.09434	train-rmse:2.46731
# [1782]	eval-rmse:2.09434	train-rmse:2.46725
# [1783]	eval-rmse:2.09436	train-rmse:2.46719
# [1784]	eval-rmse:2.09435	train-rmse:2.46716
# [1785]	eval-rmse:2.09433	train-rmse:2.46713
# [1786]	eval-rmse:2.09433	train-rmse:2.4671
# [1787]	eval-rmse:2.09433	train-rmse:2.46702
# [1788]	eval-rmse:2.0943	train-rmse:2.46698
# [1789]	eval-rmse:2.09429	train-rmse:2.46695
# [1790]	eval-rmse:2.09429	train-rmse:2.46691
# [1791]	eval-rmse:2.0943	train-rmse:2.46688
# [1792]	eval-rmse:2.09429	train-rmse:2.46686
# [1793]	eval-rmse:2.09431	train-rmse:2.46679
# [1794]	eval-rmse:2.09431	train-rmse:2.46671
# [1795]	eval-rmse:2.09428	train-rmse:2.46665
# [1796]	eval-rmse:2.09429	train-rmse:2.46659
# [1797]	eval-rmse:2.09428	train-rmse:2.46656
# [1798]	eval-rmse:2.09428	train-rmse:2.46652
# [1799]	eval-rmse:2.09427	train-rmse:2.46648
# [1800]	eval-rmse:2.09425	train-rmse:2.46643
# [1801]	eval-rmse:2.09425	train-rmse:2.46641
# [1802]	eval-rmse:2.09424	train-rmse:2.46637
# [1803]	eval-rmse:2.09426	train-rmse:2.46635
# [1804]	eval-rmse:2.09427	train-rmse:2.46631
# [1805]	eval-rmse:2.09427	train-rmse:2.46626
# [1806]	eval-rmse:2.09428	train-rmse:2.46621
# [1807]	eval-rmse:2.09432	train-rmse:2.46616
# [1808]	eval-rmse:2.09434	train-rmse:2.46614
# [1809]	eval-rmse:2.09433	train-rmse:2.4661
# [1810]	eval-rmse:2.09432	train-rmse:2.46607
# [1811]	eval-rmse:2.09431	train-rmse:2.46605
# [1812]	eval-rmse:2.09432	train-rmse:2.46602
# [1813]	eval-rmse:2.09434	train-rmse:2.46597
# [1814]	eval-rmse:2.09433	train-rmse:2.46594
# [1815]	eval-rmse:2.09434	train-rmse:2.46592
# [1816]	eval-rmse:2.09432	train-rmse:2.46585
# [1817]	eval-rmse:2.09432	train-rmse:2.4658
# [1818]	eval-rmse:2.09431	train-rmse:2.46578
# [1819]	eval-rmse:2.09432	train-rmse:2.46571
# [1820]	eval-rmse:2.09431	train-rmse:2.46567
# [1821]	eval-rmse:2.09431	train-rmse:2.46564
# [1822]	eval-rmse:2.09427	train-rmse:2.46563
# [1823]	eval-rmse:2.09428	train-rmse:2.4656
# [1824]	eval-rmse:2.09428	train-rmse:2.46556
# [1825]	eval-rmse:2.09431	train-rmse:2.46554
# [1826]	eval-rmse:2.09431	train-rmse:2.46549
# [1827]	eval-rmse:2.09431	train-rmse:2.46547
# [1828]	eval-rmse:2.09432	train-rmse:2.46544
# [1829]	eval-rmse:2.0943	train-rmse:2.46535
# [1830]	eval-rmse:2.0943	train-rmse:2.46532
# [1831]	eval-rmse:2.09426	train-rmse:2.46524
# [1832]	eval-rmse:2.09426	train-rmse:2.46521
# [1833]	eval-rmse:2.09427	train-rmse:2.46515
# [1834]	eval-rmse:2.09427	train-rmse:2.46509
# [1835]	eval-rmse:2.09427	train-rmse:2.46505
# [1836]	eval-rmse:2.09425	train-rmse:2.46497
# [1837]	eval-rmse:2.09427	train-rmse:2.46495
# [1838]	eval-rmse:2.09427	train-rmse:2.46493
# [1839]	eval-rmse:2.09427	train-rmse:2.46486
# [1840]	eval-rmse:2.09424	train-rmse:2.46481
# [1841]	eval-rmse:2.09423	train-rmse:2.46479
# [1842]	eval-rmse:2.09424	train-rmse:2.46474
# [1843]	eval-rmse:2.09424	train-rmse:2.4647
# [1844]	eval-rmse:2.09429	train-rmse:2.46465
# [1845]	eval-rmse:2.09431	train-rmse:2.46463
# [1846]	eval-rmse:2.0943	train-rmse:2.46457
# [1847]	eval-rmse:2.09428	train-rmse:2.4645
# [1848]	eval-rmse:2.09429	train-rmse:2.46446
# [1849]	eval-rmse:2.0943	train-rmse:2.46442
# [1850]	eval-rmse:2.0943	train-rmse:2.46439
# [1851]	eval-rmse:2.0943	train-rmse:2.46437
# [1852]	eval-rmse:2.09429	train-rmse:2.46435
# [1853]	eval-rmse:2.09425	train-rmse:2.46431
# [1854]	eval-rmse:2.09428	train-rmse:2.46428
# [1855]	eval-rmse:2.09428	train-rmse:2.46426
# [1856]	eval-rmse:2.09428	train-rmse:2.46423
# [1857]	eval-rmse:2.09429	train-rmse:2.46416
# [1858]	eval-rmse:2.0943	train-rmse:2.46414
# [1859]	eval-rmse:2.09431	train-rmse:2.46409
# [1860]	eval-rmse:2.0943	train-rmse:2.46406
# [1861]	eval-rmse:2.09427	train-rmse:2.46399
# [1862]	eval-rmse:2.09426	train-rmse:2.46394
# [1863]	eval-rmse:2.09432	train-rmse:2.4639
# [1864]	eval-rmse:2.09433	train-rmse:2.46386
# [1865]	eval-rmse:2.09431	train-rmse:2.4638
# [1866]	eval-rmse:2.09431	train-rmse:2.46377
# [1867]	eval-rmse:2.09431	train-rmse:2.46373
# [1868]	eval-rmse:2.09432	train-rmse:2.46361
# [1869]	eval-rmse:2.09432	train-rmse:2.46357
# [1870]	eval-rmse:2.09428	train-rmse:2.46352
# [1871]	eval-rmse:2.09426	train-rmse:2.46349
# [1872]	eval-rmse:2.09425	train-rmse:2.46347
# [1873]	eval-rmse:2.09425	train-rmse:2.46345
# [1874]	eval-rmse:2.09426	train-rmse:2.4634
# [1875]	eval-rmse:2.09426	train-rmse:2.46336
# [1876]	eval-rmse:2.09426	train-rmse:2.46332
# [1877]	eval-rmse:2.09426	train-rmse:2.46326
# [1878]	eval-rmse:2.09427	train-rmse:2.46321
# [1879]	eval-rmse:2.09427	train-rmse:2.46317
# [1880]	eval-rmse:2.09428	train-rmse:2.46311
# [1881]	eval-rmse:2.09427	train-rmse:2.46306
# [1882]	eval-rmse:2.09425	train-rmse:2.46302
# [1883]	eval-rmse:2.09426	train-rmse:2.46298
# [1884]	eval-rmse:2.09425	train-rmse:2.46295
# [1885]	eval-rmse:2.09425	train-rmse:2.46291
# [1886]	eval-rmse:2.09424	train-rmse:2.46287
# [1887]	eval-rmse:2.09428	train-rmse:2.46284
# [1888]	eval-rmse:2.09426	train-rmse:2.46277
# [1889]	eval-rmse:2.09426	train-rmse:2.46269
# [1890]	eval-rmse:2.09426	train-rmse:2.46265
# [1891]	eval-rmse:2.09426	train-rmse:2.46262
# [1892]	eval-rmse:2.09426	train-rmse:2.46256
# [1893]	eval-rmse:2.09423	train-rmse:2.46252
# [1894]	eval-rmse:2.09424	train-rmse:2.4625
# [1895]	eval-rmse:2.09424	train-rmse:2.46245
# [1896]	eval-rmse:2.09424	train-rmse:2.46242
# [1897]	eval-rmse:2.09422	train-rmse:2.4624
# [1898]	eval-rmse:2.09422	train-rmse:2.46235
# [1899]	eval-rmse:2.09422	train-rmse:2.4623
# [1900]	eval-rmse:2.09422	train-rmse:2.46227
# [1901]	eval-rmse:2.09425	train-rmse:2.46224
# [1902]	eval-rmse:2.09425	train-rmse:2.46221
# [1903]	eval-rmse:2.09426	train-rmse:2.46215
# [1904]	eval-rmse:2.09427	train-rmse:2.46209
# [1905]	eval-rmse:2.09425	train-rmse:2.46206
# [1906]	eval-rmse:2.09425	train-rmse:2.46203
# [1907]	eval-rmse:2.09425	train-rmse:2.462
# [1908]	eval-rmse:2.09428	train-rmse:2.46192
# [1909]	eval-rmse:2.09428	train-rmse:2.46187
# [1910]	eval-rmse:2.09431	train-rmse:2.46183
# [1911]	eval-rmse:2.09432	train-rmse:2.4618
# [1912]	eval-rmse:2.09432	train-rmse:2.46176
# [1913]	eval-rmse:2.09432	train-rmse:2.46173
# [1914]	eval-rmse:2.09432	train-rmse:2.46168
# [1915]	eval-rmse:2.0943	train-rmse:2.46163
# [1916]	eval-rmse:2.0943	train-rmse:2.46159
# [1917]	eval-rmse:2.09434	train-rmse:2.46154
# [1918]	eval-rmse:2.09434	train-rmse:2.46151
# [1919]	eval-rmse:2.09433	train-rmse:2.46146
# [1920]	eval-rmse:2.09432	train-rmse:2.46137
# [1921]	eval-rmse:2.09432	train-rmse:2.46133
# [1922]	eval-rmse:2.09429	train-rmse:2.4613
# [1923]	eval-rmse:2.09429	train-rmse:2.46126
# [1924]	eval-rmse:2.09427	train-rmse:2.46124
# [1925]	eval-rmse:2.09426	train-rmse:2.46117
# [1926]	eval-rmse:2.09425	train-rmse:2.46114
# [1927]	eval-rmse:2.09427	train-rmse:2.46108
# [1928]	eval-rmse:2.09425	train-rmse:2.46106
# [1929]	eval-rmse:2.09425	train-rmse:2.46102
# [1930]	eval-rmse:2.09426	train-rmse:2.46098
# [1931]	eval-rmse:2.09426	train-rmse:2.46096
# [1932]	eval-rmse:2.09427	train-rmse:2.46093
# [1933]	eval-rmse:2.09428	train-rmse:2.4609
# [1934]	eval-rmse:2.09428	train-rmse:2.46084
# [1935]	eval-rmse:2.09429	train-rmse:2.46078
# [1936]	eval-rmse:2.09429	train-rmse:2.46072
# [1937]	eval-rmse:2.0943	train-rmse:2.46067
# [1938]	eval-rmse:2.09424	train-rmse:2.46063
# [1939]	eval-rmse:2.09423	train-rmse:2.46058
# [1940]	eval-rmse:2.09422	train-rmse:2.46054
# [1941]	eval-rmse:2.09423	train-rmse:2.46052
# [1942]	eval-rmse:2.09422	train-rmse:2.46046
# [1943]	eval-rmse:2.09422	train-rmse:2.46043
# [1944]	eval-rmse:2.09423	train-rmse:2.46041
# [1945]	eval-rmse:2.09425	train-rmse:2.46035
# [1946]	eval-rmse:2.09424	train-rmse:2.46028
# [1947]	eval-rmse:2.09423	train-rmse:2.46024
# [1948]	eval-rmse:2.09421	train-rmse:2.46023
# [1949]	eval-rmse:2.09419	train-rmse:2.46016
# [1950]	eval-rmse:2.09419	train-rmse:2.46014
# [1951]	eval-rmse:2.0942	train-rmse:2.46012
# [1952]	eval-rmse:2.0942	train-rmse:2.46003
# [1953]	eval-rmse:2.0942	train-rmse:2.46001
# [1954]	eval-rmse:2.09419	train-rmse:2.45998
# [1955]	eval-rmse:2.0942	train-rmse:2.45994
# [1956]	eval-rmse:2.09421	train-rmse:2.45993
# [1957]	eval-rmse:2.09418	train-rmse:2.4599
# [1958]	eval-rmse:2.09416	train-rmse:2.45987
# [1959]	eval-rmse:2.09416	train-rmse:2.45983
# [1960]	eval-rmse:2.09414	train-rmse:2.4598
# [1961]	eval-rmse:2.09412	train-rmse:2.45975
# [1962]	eval-rmse:2.09412	train-rmse:2.45972
# [1963]	eval-rmse:2.09415	train-rmse:2.45968
# [1964]	eval-rmse:2.09417	train-rmse:2.45965
# [1965]	eval-rmse:2.0942	train-rmse:2.4596
# [1966]	eval-rmse:2.09421	train-rmse:2.45957
# [1967]	eval-rmse:2.09419	train-rmse:2.45955
# [1968]	eval-rmse:2.09417	train-rmse:2.45949
# [1969]	eval-rmse:2.09419	train-rmse:2.45947
# [1970]	eval-rmse:2.09418	train-rmse:2.45942
# [1971]	eval-rmse:2.09418	train-rmse:2.45939
# [1972]	eval-rmse:2.09418	train-rmse:2.45937
# [1973]	eval-rmse:2.09418	train-rmse:2.45932
# [1974]	eval-rmse:2.09418	train-rmse:2.4593
# [1975]	eval-rmse:2.09419	train-rmse:2.45927
# [1976]	eval-rmse:2.09412	train-rmse:2.4592
# [1977]	eval-rmse:2.09413	train-rmse:2.45917
# [1978]	eval-rmse:2.09413	train-rmse:2.45911
# [1979]	eval-rmse:2.09414	train-rmse:2.45907
# [1980]	eval-rmse:2.09413	train-rmse:2.45905
# [1981]	eval-rmse:2.09414	train-rmse:2.45901
# [1982]	eval-rmse:2.09412	train-rmse:2.45899
# [1983]	eval-rmse:2.09413	train-rmse:2.45895
# [1984]	eval-rmse:2.09411	train-rmse:2.45891
# [1985]	eval-rmse:2.09411	train-rmse:2.45887
# [1986]	eval-rmse:2.0941	train-rmse:2.45884
# [1987]	eval-rmse:2.09411	train-rmse:2.45879
# [1988]	eval-rmse:2.0941	train-rmse:2.45876
# [1989]	eval-rmse:2.09409	train-rmse:2.45874
# [1990]	eval-rmse:2.09408	train-rmse:2.45872
# [1991]	eval-rmse:2.09408	train-rmse:2.45864
# [1992]	eval-rmse:2.09409	train-rmse:2.45862
# [1993]	eval-rmse:2.0941	train-rmse:2.45859
# [1994]	eval-rmse:2.09411	train-rmse:2.45853
# [1995]	eval-rmse:2.09411	train-rmse:2.45851
# [1996]	eval-rmse:2.09412	train-rmse:2.45845
# [1997]	eval-rmse:2.0941	train-rmse:2.45843
# [1998]	eval-rmse:2.09408	train-rmse:2.45836
# [1999]	eval-rmse:2.09407	train-rmse:2.45831
# Model 2

# %%
def simple_fe(df):
    df['lag_t7'] = df.groupby(['id'])['demand'].transform(lambda x: x.shift(7)).astype(np.float16)
    df['lag_t14'] = df.groupby(['id'])['demand'].transform(lambda x: x.shift(14)).astype(np.float16)
    df['lag_t21'] = df.groupby(['id'])['demand'].transform(lambda x: x.shift(21)).astype(np.float16)
    df['lag_t28'] = df.groupby(['id'])['demand'].transform(lambda x: x.shift(28)).astype(np.float16)
    for i in [7,14,21]:
        for j in [7,14,30,45,60]:
            df['rolling_mean'+str(i)+'_t'+str(j)] = df.groupby(['id'])['demand'].transform(lambda x: x.shift(i).rolling(j).mean()).astype(np.float16)
    return df

# %%
def get_test7(df, coe, model, store_id):
    data0 = df[df['store_id'] == store_id].copy()
    print('First 7')
    test = data0[(data0['date'] > '2016-04-24') & (data0['date'] <= '2016-05-01')]
    data0.loc[(data0['date'] > '2016-04-24') & (data0['date'] <= '2016-05-01'), 'demand'] = model.predict(test[zfeatures])*coe
    print('Second 7')
    data0 = simple_fe(data0)
    test = data0[(data0['date'] > '2016-05-01') & (data0['date'] <= '2016-05-08')]
    data0.loc[(data0['date'] > '2016-05-01') & (data0['date'] <= '2016-05-08'), 'demand'] = model.predict(test[zfeatures])*coe
    print('Third 7')
    data0 = simple_fe(data0)
    test = data0[(data0['date'] > '2016-05-08') & (data0['date'] <= '2016-05-15')]
    data0.loc[(data0['date'] > '2016-05-08') & (data0['date'] <= '2016-05-15'), 'demand'] = model.predict(test[zfeatures])*coe
    print('Forth 7')
    data0 = simple_fe(data0)
    test = data0[(data0['date'] > '2016-05-15') & (data0['date'] <= '2016-05-22')]
    data0.loc[(data0['date'] > '2016-05-15') & (data0['date'] <= '2016-05-22'), 'demand'] = model.predict(test[zfeatures])*coe
    return data0[(data0['date'] > '2016-04-24') & (data0['date'] <= '2016-05-22')]

# %%
# %%time
coe = [1.025, 1.025, 1.025, 1.025, 1.025, 1.025, 1.025, 1.025, 1.025, 1.025]
for i in range(10):
    model_name = 'store_' + str(i) + '.sav'
    model = joblib.load(model_name)
    print('Test on store', i+1)
    if i == 0:
        test = get_test7(data1, 1, model, i)
    else:
        test = pd.concat([test, get_test7(data1, 1, model, i)], axis = 0)

# %%
# 生成提交文件
sample_submission = pd.read_csv('./sample_submission.csv')
predictions = test[['id', 'date', 'demand']]
predictions = pd.pivot(predictions, index='id', columns='date', values='demand').reset_index()
predictions.columns = ['id'] + ['F' + str(i + 1) for i in range(28)]

evaluation_rows = [row for row in sample_submission['id'] if 'evaluation' in row]
evaluation = sample_submission[sample_submission['id'].isin(evaluation_rows)]

validation = sample_submission[['id']].merge(predictions, on='id')
final = pd.concat([validation, evaluation])
df = final.copy()
columns_list = df.columns[:]
submission = df[columns_list]
final.to_csv('./submission_acc2.csv', index=False)
